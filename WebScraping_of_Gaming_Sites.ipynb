# %% [markdown]
# # WebScraping of Gaming Sites [(View)](https://www.y8.com/)

# %% [markdown]
# ![image](https://i.imgur.com/dLB0NVQ.jpg)
#
#
# - [Y8.com](https://www.y8.com/#:~:text=Y8.com%20is%20home%20for,HTML5%20games%20will%20suit%20you.) is home for gamers on any device.
# - Play phone games or get rich 3D graphics on desktops by playing WebGL Games.
# - Otherwise, if your preference is casual 2D worlds, then HTML5 games will suit you.
# - Founded in 2006, Y8.com is a game development site and a growing community that caters to thousands of free games formats
# - Its supported by Adobe Flash Player, Unity 3D, HTML5, Android, and Java.
# - Most of us indeed relished playing various browser games during Y8's glory days back in 2007-2008.
# - Competitors of [Y8.com](https://www.y8.com/#:~:text=Y8.com%20is%20home%20for,HTML5%20games%20will%20suit%20you.) are: [agame.com](https://www.agame.com/), [friv.com](https://www.friv.com/), [poki.com](https://poki.com/), [twoplayergames.org](https://www.twoplayergames.org/)
# - Hereby we have a list of gaming catagories based on that we can extract data information by using [WebScraping](https://www.geeksforgeeks.org/python-web-scraping-tutorial/).

# %% [markdown]
# ### [Web Scraping ](https://www.geeksforgeeks.org/python-web-scraping-tutorial/)
#
#
# # ![banner-image](https://i.imgur.com/owoOoCy.png)
#
#
#
# - Technique of extracting large amounts of data from websites where the extracted data is saved in a local file on your device.
#
# - The simplest form of Web scraping is manually copying and pasting data from a web page into a text file or spreadsheet.
#
# - Sometimes this is the only solution when the websites set up barriers.
#
# - But in most cases, a huge amount of data is required which is difficult for a human to scrape.
#
# - Therefore, we have Web scraping tools to automate the process.
#
# - we will use `requests` and `BeautifulSoup` libraries to scrape data from [Y8.com](https://www.y8.com/#:~:text=Y8.com%20is%20home%20for,HTML5%20games%20will%20suit%20you.)
#
# Outline-Steps we've to process:
#
# 1. Download the web page using requests.
# 2. Parse the html document using BeautifulSoup.
# 3. Extract Game Name, Technologu used, Rating, Number of Players.
# 4. Compile extracted information into lists and dictionaries.
# 5. Read and save the extracted information as CSV files.
# 6. Combine data from multiple pages.
#
# Libraries to be used in this:-
#
# * [requests](https://requests.readthedocs.io/en/latest/)
#
# * [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# * [pandas](https://www.geeksforgeeks.org/introduction-to-pandas-in-python/)

# %% [markdown]
# ### Step:1 - Download the WebPage using `requests`
#
# We'll use a library called [requests](https://requests.readthedocs.io/en/latest/) to download web pages from the internet. Let's begin by installing and importing the library.

# %%
! pip install requests --upgrade --quiet

# %% [markdown]
# The above library `requests` is installed and we need to import the same

# %%
import requests

# %% [markdown]
# Need to Select the topic/categories from websites
#
# ![image](https://i.imgur.com/69JD5hb.jpg)
#
# From the Gaming categories i have choose `Action-Adventure`

# %%
topic_url = 'https://www.y8.com/categories/action_adventure'

# %% [markdown]
# To download a page, we can use `.get` function from `requests`, which returns `response`

# %%
response = requests.get(topic_url)

# %%
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# requests.get returns a response object with the page contents and some information indicating whether the request was successful, using a status code.
#
# Learn more about HTTP status codes here: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status
#
# If the request was successful, `response.status_code` is set to a value between `200` and `299`.

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# The contents of the web page can be accessed using the `.text` property of the `response`

# %%
content = response.text

# %%
len(content)
# Out:
# 287757

# %%
content
# Out:
# '<!DOCTYPE html>\n<html class="no-touch" lang="en"\n      dir="ltr">\n  <head>\n    <meta charset="utf-8">\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"64ea7759b2","applicationID":"2972689","transactionName":"eltWERRfXFtVQB5WVU1RXwoUWVVEH0FZWkM=","queueTime":1,"applicationTime":275,"agent":""}</script>\n<script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"VwcCU1ZVGwEJU1NUDwg=",licenseKey:"64ea7759b2",applicationID:"2972689"};;(()=>{var e,t,r={9071:(e,t,r)=>{"use strict";r.d(t,{I:()=>n});var n=0,i=navigator.userAgent.match(/Firefox[\\/\\s](\\d+\\.\\d+)/);i&&(n=+i[1])},6562:(e,t,r)=>{"use strict";r.d(t,{P_:()=>p,Mt:()=>v,C5:()=>d,DL:()=>y,OP:()=>k,lF:()=>H,Yu:()=>E,Dg:()=>g,CX:()=>f,GE:()=>w,sU:()=>L});var n={};r.r(n),r.d(n,{agent:()=>x,match:()=>_,version:()=>O});var i=r(6797),o=r(909),a=r(8610);class s{constructor(e,t){try{if(!e||"object"!=typeof e)return(0,a.Z)("New setting a Configurable requires an object as input");if(!t||"object"!=typeof t)return(0,a.Z)("Setting a Configurable requires a model to set its initial properties");Object.assign(this,t),Object.entries(e).forEach((e=>{let[t,r]=e;const n=(0,o.q)(t);n.length&&r&&"object"==typeof r&&n.forEach((e=>{e in r&&((0,a.Z)(\'"\'.concat(e,\'" is a protected attribute and can not be changed in feature \').concat(t,".  It will have no effect.")),delete r[e])})),this[t]=r}))}catch(e){(0,a.Z)("An error occured while setting a Configurable",e)}}}const c={beacon:i.ce.beacon,errorBeacon:i.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},u={};function d(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!u[e])throw new Error("Info for ".concat(e," was never set"));return u[e]}function f(e,t){if(!e)throw new Error("All info objects require an agent identifier!");u[e]=new s(t,c),(0,i.Qy)(e,u[e],"info")}const l={allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0,harvestTimeSeconds:10},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30},session_trace:{enabled:!0,harvestTimeSeconds:10},spa:{enabled:!0,harvestTimeSeconds:10}},h={};function p(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!h[e])throw new Error("Configuration for ".concat(e," was never set"));return h[e]}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");h[e]=new s(t,l),(0,i.Qy)(e,h[e],"config")}function v(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var r=p(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const m={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},b={};function y(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!b[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return b[e]}function w(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");b[e]=new s(t,m),(0,i.Qy)(e,b[e],"loader_config")}const E=(0,i.mF)().o;var A=r(2053),x=null,O=null;if(navigator.userAgent){var T=navigator.userAgent,S=T.match(/Version\\/(\\S+)\\s+Safari/);S&&-1===T.indexOf("Chrome")&&-1===T.indexOf("Chromium")&&(x="Sa ...

# %% [markdown]
# Let's save the contents to a file with the `.html` extensions

# %%
with open('Games.html', 'w') as file:
    file.write(content)

# %% [markdown]
# From the above one you can view the file by click on the "File>Open" menu option within Jupyter and clicking on `Games.html` in the list of files displayed.
#
# ![img1](https://i.imgur.com/snQ44To.jpg)
# ![img2](https://i.imgur.com/kOXzO0z.jpg)

# %% [markdown]
# We have successfully downloaded the webpage

# %% [markdown]
# ### Step:2 - Extracting information from HTML using Beautiful Soup
#
# To extract information from the HTML source code of a webpage programmatically, we can use the [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) library.

# %%
! pip install BeautifulSoup4 --upgrade --quiet

# %% [markdown]
# The above library `BeautifulSoup4` is installed and we need to import the same

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# From the below, read the contents of the file `Games.html` and create a `BeautifulSoup` object to parse the content

# %%
with open ('Games.html', 'r') as file:
    html_source = file.read()

# %%
len(html_source)
# Out:
# 287757

# %%
html_source
# Out:
# '<!DOCTYPE html>\n<html class="no-touch" lang="en"\n      dir="ltr">\n  <head>\n    <meta charset="utf-8">\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"64ea7759b2","applicationID":"2972689","transactionName":"eltWERRfXFtVQB5WVU1RXwoUWVVEH0FZWkM=","queueTime":1,"applicationTime":275,"agent":""}</script>\n<script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"VwcCU1ZVGwEJU1NUDwg=",licenseKey:"64ea7759b2",applicationID:"2972689"};;(()=>{var e,t,r={9071:(e,t,r)=>{"use strict";r.d(t,{I:()=>n});var n=0,i=navigator.userAgent.match(/Firefox[\\/\\s](\\d+\\.\\d+)/);i&&(n=+i[1])},6562:(e,t,r)=>{"use strict";r.d(t,{P_:()=>p,Mt:()=>v,C5:()=>d,DL:()=>y,OP:()=>k,lF:()=>H,Yu:()=>E,Dg:()=>g,CX:()=>f,GE:()=>w,sU:()=>L});var n={};r.r(n),r.d(n,{agent:()=>x,match:()=>_,version:()=>O});var i=r(6797),o=r(909),a=r(8610);class s{constructor(e,t){try{if(!e||"object"!=typeof e)return(0,a.Z)("New setting a Configurable requires an object as input");if(!t||"object"!=typeof t)return(0,a.Z)("Setting a Configurable requires a model to set its initial properties");Object.assign(this,t),Object.entries(e).forEach((e=>{let[t,r]=e;const n=(0,o.q)(t);n.length&&r&&"object"==typeof r&&n.forEach((e=>{e in r&&((0,a.Z)(\'"\'.concat(e,\'" is a protected attribute and can not be changed in feature \').concat(t,".  It will have no effect.")),delete r[e])})),this[t]=r}))}catch(e){(0,a.Z)("An error occured while setting a Configurable",e)}}}const c={beacon:i.ce.beacon,errorBeacon:i.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},u={};function d(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!u[e])throw new Error("Info for ".concat(e," was never set"));return u[e]}function f(e,t){if(!e)throw new Error("All info objects require an agent identifier!");u[e]=new s(t,c),(0,i.Qy)(e,u[e],"info")}const l={allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0,harvestTimeSeconds:10},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30},session_trace:{enabled:!0,harvestTimeSeconds:10},spa:{enabled:!0,harvestTimeSeconds:10}},h={};function p(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!h[e])throw new Error("Configuration for ".concat(e," was never set"));return h[e]}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");h[e]=new s(t,l),(0,i.Qy)(e,h[e],"config")}function v(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var r=p(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const m={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},b={};function y(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!b[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return b[e]}function w(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");b[e]=new s(t,m),(0,i.Qy)(e,b[e],"loader_config")}const E=(0,i.mF)().o;var A=r(2053),x=null,O=null;if(navigator.userAgent){var T=navigator.userAgent,S=T.match(/Version\\/(\\S+)\\s+Safari/);S&&-1===T.indexOf("Chrome")&&-1===T.indexOf("Chromium")&&(x="Sa ...

# %%
doc = BeautifulSoup(html_source, 'html.parser')

# %% [markdown]
# Inspect the `doc type` for your verification

# %%
type(doc)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### Step:3 Use Beautiful Soup to parse and extract information

# %% [markdown]
# Let's find the First tag of a and parsing the documents

# %%
doc.find('a')
# Out:
# <a aria-label="logo" class="no-event" href="https://www.y8.com/"><img alt="Y8.com" height="48" src="https://img.y8.com/assets/y8/header-logo-b39e5071cb111465fc5a5aef6496121adfcb414692d067f967434d9d80418afc.svg" width="100"/>
# </a>

# %% [markdown]
# Using reusable function in order parse and extract data from `Games.html` file

# %%
def get_topic_page(url):
    topic_url = 'https://www.y8.com/tags/' + url
    response = requests.get(topic_url)
    if response.status_code != 200:
        print('Status Code = ', response.status_code)
        raise Exception('failed to fetch web page' + topic_url)
        
    topic_doc = BeautifulSoup(response.text)
    return topic_doc

# %%
get_topic_page('action')
# Out:
# <!DOCTYPE html>
# <html class="no-touch" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0, minimal-ui" name="viewport"/>
# <meta content="#FFF" name="theme-color"/>
# <link href="https://img.y8.com" rel="preconnect"/>
# <link href="https://cdn.y8.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://account.y8.com" rel="preconnect"/>
# <link href="/y8_manifest.json" rel="manifest"/>
# <script id="gp-app-info">
# //<![CDATA[
#
#   window.appInfo = {
#     cdn: 'https://cdn.y8.com',
#     skinName: 'y8.com',
#     skinShortName: 'y8',
#     skinDomain: 'y8.com',
#     currentLocale: 'en',
#     currentKind: 'game',
#     recaptchaV3SiteKey: '6LcCYbgUAAAAAC6jOB2wXW8L59EmH3oVZr0r-qxZ',
#
#     accountServiceApiUrls: {
#       pointsBonusTimerUrl: 'https://account.y8.com/points/bonus_timer',
#       profilePointsTotalUrl: 'https://account.y8.com/api/v1/json/points/total/:uid',
#       profileJsonUrl: 'https://account.y8.com/profiles/:uid.json',
#       profilePictureUrl: 'https://account.y8.com/:uid/profile_picture/new?external=1',
#       profileAvatarUrl: 'https://account.y8.com/profiles/:uid/profile_avatar',
#       socialCounterUrl: 'https://account.y8.com/api/v1/json/idnet_social_counters?authorization_id=:uid',
#       userAutologinUrl: 'https://account.y8.com/api/user_data/autologin?callback=&app_id=:app_id',
#       userUrl: 'https://account.y8.com/user',
#       pidsUrl: 'https://account.y8.com/profiles/:profileId/list_pids'
#     },
#
#     commonCookieOptions: {
#       domain: `.y8.com`,
#       path: '/'
#     },
#
#     user: {
#       maxHeartedItems: 3,
#     },
#
#     errors: {
#       notLoggedInAndNoCaptcha: 1,
#     },
#   };
#
# //]]>
# </script>
# <script>
# //<![CDATA[
#
#     (function() {
#       window.adBlockDetected = false;
#
#       if ('fetch' in window) {
#         fetch(
#           'https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js',
#           { method: 'HEAD', redirect: 'error' }
#         ).catch(function() {
#           window.adBlockDetected = true;
#         });
#       }
#     })();
#
# //]]>
# </script>
# <title>Top Free Online Games Tagged Action 🗡 - Y8.COM</title>
# <meta content="Play action games at Y8.com. If you need games that have perpetual movement and a lot of fight scenes, the action category is right for you. There is never a dull moment when enemies are always after you, fight them off to reach the next level." name="description"/>
# <meta content="action games, action games online, play action games, free action games, y8 action, y8 action games" name="keywords"/>
# <link href="https://www.y8.com/tags/action" rel="canonical"/>
# <link href="https://www.y8.com/tags/action" hreflang="x-default" rel="alternate"/>
# <link href="https://www.y8.com/tags/action" hreflang="en" rel="alternate"/>
# <link href="https://ru.y8.com/tags/action" hreflang="ru" rel="alternate"/>
# <link href="https://fr.y8.com/tags/action" hreflang="fr" rel="alternate"/>
# <link href="https://de.y8.com/tags/action" hreflang="de" rel="alternate"/>
# <link href="https://it.y8.com/tags/action" hreflang="it" rel="alternate"/>
# <link href="https://el.y8.com/tags/action" hreflang="el" rel="alternate"/>
# <link href="https://he.y8.com/tags/action" hreflang="he" rel="alternate"/>
# <link href="https://hi.y8.com/tags/action" hreflang="hi" rel="alternate"/>
# <link href="https://ro.y8.com/tags/action" hreflang="ro" rel="alternate"/>
# <link href="https://es.y8.com/tags/action" hreflang="es" rel="alternate"/>
# <link href="https://tl.y8.com/tags/action" hreflang="tl" rel="alternate"/>
# <link href="https://th.y8.com/tags/action" hreflang="th" rel="alternate"/>
# <link href="https://zh.y8.com/tags/action" hreflang="zh" rel="alternate"/>
# <link href="https://nl.y8.com/tags/action" hreflang="nl" rel="alternate"/>
# <link href="https://vi.y8.com/tags/action" hreflang="vi" rel="alternate"/>
# <link href="https://tr.y8.com/tags/action" hreflang="tr" rel="alternate"/>
# <link href="https://pt.y8.com/tags/action" hreflang="pt" rel="alternate"/>
# <link href="https://pl.y8.com/tags/action" hreflang="pl" rel="alternate"/>
# <link href="https://ko.y8.com/tags/action" hreflang="ko" rel="alternate"/>
# <link href="https://ja.y8.com/tags/action" hreflang="ja" rel="alternate"/>
# <link href="https://id.y8.com/tags/action" hreflang="id" rel="alternate"/>
# <link href="https://ar.y8.com/tags/action" hreflang="ar" rel="alternate"/>
# <meta content="Top Free Online Games Tagged Action 🗡 - Y8.COM" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.y8.com/tags/action" property="og:url"/>
# <meta content="https://img.y8.com/assets/y8/logo-social-8740c6b841d8807a50e324495de20bc47850124ac05cecf792e7412f3f9863e0.png" property="og:image"/>
# <meta content="500" property="og:image:width"/>
# <meta content="500" property="og:image:height"/>
# <meta content="Y8.Com" property="og:site_name"/>
# <meta content="Play action games at Y8.com. If you need games that have perpetual movement and a lot of fight scenes, the action category is right for you. There is never a dull moment when enemies are always after you, fight them off to reach the next level." property="og:description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@y8_com" name="twitter:site"/>
# <meta content="https://www.y8.com/tags/action" name="twitter:url"/>
# <meta content="Top Free Online Games Tagged Action 🗡 - Y8.COM" name="twitter:title"/>
# <meta content="Play action games at Y8.com. If you need games that have perpetual movement and a lot of fight scenes, the action category is right for you. There is never a dull moment when enemies are always after you, fight them off to reach the next level." name="twitter:description"/>
# <meta content="https://img.y8.com/assets/y8/logo-social-8740c6b841d8807a50e324495de20bc47850124ac05cecf792e7412f3f9863e0.png" name="twitter:image"/>
# <script type="application/ld+json">
# {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.y8.com/categories/action_adventure","name":"Action \u0026 Adventure"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.y8.com/tags/action","name":"Action"}}]}
# </script>
# <link href="https://img.y8.com/assets/y8/favicon-32ba556e0026f47b8a6774c589575902155c4469a8116a68880669d1a5bedd0d.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://img.y8.com/mobile_launch_icons/y8-192.png" rel="icon" sizes="192x192"/>
# <link href="https://img.y8.com/mobile_launch_icons/y8-192.png" rel="apple-touch-icon"/>
# <script src="https://img.y8.com/packs/js/y8/application-2c64748bb1a941b046a3.js"></script>
# <link href="https://img.y8.com/packs/css/y8/application-8a4d8df5.css" media="screen" rel="stylesheet"/>
# <link href="https://img.y8.com/assets/y8.com/latin-8277e491a854b5fd4a681854e59a85421eae70da9050ecc8ec99dcae535bfa0f.css" media="screen" rel="stylesheet"/>
# <script src="https://img.y8.com/packs/js/controllers/tags/show-7472d9818b4d14d84c6f.js"></script>
# <link class="xhr" href="https://www.y8.com/tags/action.js" rel="alternate"/>
# <!-- Matomo -->
# <script>
#   var _paq = window._paq = window._paq || [];
#   /* tracker methods like "setCustomDimension" should be called before "trackPageView" */
#   _paq.push(['trackPageView']);
#   _paq.push(['enableLinkTracking']);
#   (function() {
#     var u="https://matomo.y8.com/";
#     _paq.push(['setTrackerUrl', u+'matomo.php']);
#     _paq.push(['setSiteId', '1']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.async=true; g.src=u+'matomo.js'; s.parentNode.insertBefore(g,s);
#   })();
# </script>
# <!-- End Matomo Code -->
# </head>
# <body class="tags show games-active" data-action="show" data-auth-success-path="/auth/idnet/callback" data-controller="Tags" data-filter-compatibility-games="true" data-items-per-page="64">
# <nav class="navbar">
# <div class="container">
# <div class="y8-navbar-left">
# <div class="mobile-burger-menu">
# <span class="burger-btn">
# <img alt="Menu" class="hamburger-icon" height="17" src="https://img.y8.com/assets/svg/hamburger-c3fe8358b513e219aa93bfd93e7b3d57991bc5741038ed7db7e71d347db0c6ae.svg" width="20"/>
# <img alt="Menu" class="hamburger-active-icon" height="16" src="https://img.y8.com/assets/svg/hamburger-active-03129c9dbc7bf62fc4cf3b24384c95eca4fafade56f0dfe54ce726cd8a718f2f.svg" width="16"/>
# </span>
# </div>
# <div class="logo">
# <a aria-label="logo" class="no-event" href="https://www.y8.com/"><img alt="Y8.com" height="48" src="https://img.y8.com/assets/y8/header-logo-b39e5071cb111465fc5a5aef6496121adfcb414692d067f967434d9d80418afc.svg" width="100"/>
# </a>
# </div>
# <div class="games-videos-switch game">
# <a href="https://www.y8.com/anim">
# <div class="games-link">games</div>
# <div class="videos-link">videos</div>
# </a>
# </div>
# <div class="mobile-search-user-container">
# <div class="search-btn">
# <img alt="Search games" height="18" src="https://img.y8.com/assets/svg/search-bf75f346b2e476637b80a6838e69801ebd3c18b1ad400fcaf8b3c1ea435da1d5.svg" width="18"/>
# </div>
# <div class="profile-btn">
# <img alt="Profile" class="profile-icon avatar" src="https://img.y8.com/assets/svg/profile-250b58e83592bb66fe437d6de217d30ee3dae674feee2ff962138996fdffde6e.svg"/>
# <img alt="Profile" class="arrow-up-icon" src="https://img.y8.com/assets/svg/arrow-up-bec5455682ee6239b995f18944808d8a0c75d7776798386efce255166669e5cf.svg"/>
# </div>
# </div>
# </div><!--
# --><form accept-charset="UTF-8" action="/search" class="navbar-form" id="items-search-form" method="get">
# <input id="kind" name="kind" type="hidden" value="game"/>
# <input class="form-control query fake-button" id="q" maxlength="50" minlength="2" name="q" onblur="setCustomValidity('')" oninvalid="setCustomValidity('Must be in between 2 and 50')" pattern=".{2,50}" placeholder="Search games" required="required" type="text"/>
# <button aria-label="Search" type="submit">
# <i class="glyphicon glyphicon-search"></i>
# </button>
# <span class="close-search-form"></span>
# </form><!--
# --><div class="y8-navbar-right">
# <div class="fake-button js-top-menu two-lines btn-header-actions new-games" data-menu="newgames">
#               New Games
#             <span class="sub-title">
#                 Next in
#               <span class="release-countdown" data-animation-frequency="4" data-game-frequency="2">00:00</span>
# </span>
# </div><!--
# --><div class="newgames-menu sub-menu">
# <div class="newgames-container">
# <ul>
# <li>
# <a class="new_games" href="/new/games" title="Y8 Games : Free online games at Y8.com">
# <div class="name">
#             Newest Games
#         </div>
# <div class="number" id="new-items-count-next-in">
#           Next addition in
#           <span class="release-countdown" data-animation-frequency="4" data-game-frequency="2">00:00</span>
# </div>
# </a> </li>
# <li class="hr"></li>
# <li>
# <a class="best_new_games" href="/best" rel="nofollow" title="Y8 Games : Free online games at Y8.com">
# <div class="name">
#             Best New Games
#         </div>
# <div class="number" id="new-items-count-best-games">
#             Best games from last 2 months
#         </div>
# </a> </li>
# </ul>
# </div>
# </div><!--
# --><div class="fake-button js-top-menu two-lines btn-header-actions browse" data-menu="browse">
#             Categories
#             <span class="sub-title">
#               &amp; more
#             </span>
# <div class="with-notification"></div>
# </div><!--
# --><div class="browse-menu sub-menu">
# <div class="browse-container">
# <div class="label-uppercase">
#     LIBRARY
#   </div>
# <ul>
# <li>
# <a class="new_games" href="/new/games" title="Y8 Games : Free online games at Y8.com">
# <div class="name">
#             New Games
#         </div>
# <div class="number" id="new-items-count-next-in-browse">
#           Next in
#           <span class="release-countdown" data-animation-frequency="4" data-game-frequency="2">00:00</span>
# </div>
# </a> </li>
# <li>
# <a class="best_new_games" href="/best" rel="nofollow" title="Y8 Games : Free online games at Y8.com">
# <div class="name">
#             Best of new games
#         </div>
# <div class="number" id="new-items-count-best-page">
#           621
#           games
#         </div>
# </a> </li>
# <li>
# <a class="popular_games" href="https://www.y8.com/popular/games" rel="nofollow" title="Y8 Games : Free online games at Y8.com">
# <div class="name">
#             Most Popular Games
#         </div>
# <div class="number" id="new-items-count-popular-page">
#           7952
#           games
#         </div>
# </a> </li>
# <li>
# <a class="played_games visited_items" href="/profile/played_games" rel="nofollow" style="text-decoration:none;">
# <div class="name">Played Games</div>
# <div class="number" id="visited-items-count"></div>
# </a> </li>
# <li>
# <a class="liked_games liked_items" href="/profile/liked_games" rel="nofollow" style="text-decoration:none;">
# <div class="name">Liked Games</div>
# <div class="number" id="liked-items-count"></div>
# </a> </li>
# <li>
# <a class="recommended_games recommended_items" href="/profile/recommended_games" rel="nofollow" style="text-decoration:none;">
# <div class="name">Recommended Games</div>
# <div class="number" id="recommended-items-count"></div>
# </a> </li>
# </ul>
# <hr/>
# <div class="label-uppercase">
#     CATEGORIES
#   </div>
# <ul>
# <!-- DO NOT CHANGE THIS : -->
# <li class="inactive girls li-category">
# <a class="girls" href="/categories/girls" title="Top Free Online Games tagged for Girls 👧 - Y8.com"><span class="name">For Girls</span>
# <span class="number">3,032 games</span>
# </a>
# </li> <li class="inactive driving_racing li-category">
# <a class="driving_racing" href="/categories/driving_racing" title="Top Free Online Games tagged Driving &amp; Racing 🏎 - Y8.com"><span class="name">Driving &amp; Racing</span>
# <span class="number">1,634 games</span>
# </a>
# </li> <li class="inactive strategy li-category">
# <a class="strategy" href="/categories/strategy" title="Top Free Online Games tagged Strategy &amp; RPG ♘ - Y8.com"><span class="name">Strategy &amp; RPG</span>
# <span class="number">293 games</span>
# </a>
# </li> <li class="inactive management li-category">
# <a class="management" href="/categories/management" title="Top Free Online Games tagged Management &amp; Sim 💼 - Y8.com"><span class="name">Management &amp; Sim</span>
# <span class="number">359 games</span>
# </a>
# </li> <li class="inactive thinking li-category">
# <a class="thinking" href="/categories/thinking" title="Top Free Online Games tagged Thinking 🤔 - Y8.com"><span class="name">Thinking</span>
# <span class="number">3,141 games</span>
# </a>
# </li> <li class="inactive action_adventure li-category">
# <a class="action_adventure" href="/categories/action_adventure" title="Top Free Online Games tagged Action &amp; Adventure 🎬 - Y8.com"><span class="name">Action &amp; Adventure</span>
# <span class="number">3,426 games</span>
# </a>
# </li> <li class="active sports li-category">
# <a class="sports" href="/categories/sports" title="Top Free Online Games tagged Sports ⚽ - Y8.com"><span class="name">Sports</span>
# <span class="number">867 games</span>
# </a>
# </li> <li class="inactive shooting li-category">
# <a class="shooting" href="/categories/shooting" title="Top Free Online Games tagged Shooting 🔫 - Y8.com"><span class="name">Shooting</span>
# <span class="number">1,723 games</span>
# </a>
# </li> <li class="inactive fighting li-category">
# <a class="fighting" href="/categories/fighting" title="Top Free Online Games tagged Fighting ⚔ - Y8.com"><span class="name">Fighting</span>
# <span class="number">279 games</span>
# </a>
# </li> <li class="inactive skill li-category">
# <a class="skill" href="/categories/skill" title="Top Free Online Games tagged Skill 🖱 - Y8.com"><span class="name">Skill</span>
# <span class="number">5,811 games</span>
# </a>
# </li> <li class="inactive arcade_classic li-category">
# <a class="arcade_classic" href="/categories/arcade_classic" title="Top Free Online Games tagged Arcade &amp; Classic 🕹 - Y8.com"><span class="name">Arcade &amp; Classic</span>
# <span class="number">5,728 games</span>
# </a>
# </li> <li class="inactive fun li-category">
# <a class="fun" href="/categories/fun" title="Top Free Online Games tagged Fun &amp; Crazy 🤪 - Y8.com"><span class="name">Fun &amp; Crazy</span>
# <span class="number">671 games</span>
# </a>
# </li> <!-- END OF : DO NOT CHANGE THIS -->
# </ul>
# </div>
# <div class="sub-menu-footer sub-menu-footer-grey">
# <!-- DO NOT CHANGE THIS, NEITHER IT'S CONTENT -->
# <div class="stats">
# <div class="text-uppercase">
#     Play with friends <br/>
#     Powered by Y8 Account
#   </div>
# <div class="stat">
# <a href="/tags/y8_account/multiplayer" rel="nofollow">
# <div class="number">
#         131
#       </div>
# <div class="description">
#         Y8 Multiplayer
#       </div>
# <div>
#         Games
#       </div>
# </a> </div>
# <div class="stat">
# <a href="/tags/y8_highscore" rel="nofollow" title="Top Free Online Games Tagged Y8 Highscore - Y8.COM">
# <div class="number">
#         1,717
#       </div>
# <div class="description">
#         Y8 High Score
#       </div>
# <div>
#         Games
#       </div>
# </a> </div>
# <div class="stat">
# <a href="/tags/y8_achievements" rel="nofollow" title="Top Free Online Games Tagged Y8 Achievements - Y8.COM">
# <div class="number">
#         1,081
#       </div>
# <div class="description">
#         Y8 Achievements
#       </div>
# <div>
#         Games
#       </div>
# </a> </div>
# <div class="stat">
# <a href="/tags/y8_screenshot" rel="nofollow" title="Top Free Online Games Tagged Y8 Screenshot - Y8.COM">
# <div class="number">
#         562
#       </div>
# <div class="description">
#         Y8 Screenshots
#       </div>
# <div>
#         Games
#       </div>
# </a> </div>
# <div class="stat">
# <a href="/tags/y8_save" rel="nofollow" title="Top Free Online Games Tagged Y8 Save - Y8.COM">
# <div class="number">
#         1,400
#       </div>
# <div class="description">
#         Y8 Online Save
#       </div>
# <div>
#         Games
#       </div>
# </a> </div>
# <div class="stat">
# <a href="/tags/y8_account" rel="nofollow" title="Top Free Online Games Tagged Y8 Account - Y8.COM">
# <div class="number">
#         2,491
#       </div>
# <div class="description">
#         All Y8 Games
#       </div>
# <div>
#         Games
#       </div>
# </a> </div>
# </div>
# <div class="last-highscore">
# <div class="text-uppercase" style="padding:0;">Last Highscore:</div>
# <div class="author-points">
# <a class="author-points__avatar" href="/users/63f050601f76dd27dab35d34/KrispyKreme" rel="nofollow" style="background-image: url('https://cdn.y8.com/profile_pictures/7d160305e159405db05a8db82bc83955-large.jpg')" target="_blank"></a>
# <div class="author-points__text">
# <b>1,536</b>
#         points on
#         <a href="https://www.y8.com/games/death_run_3d" rel="noreferrer" target="_blank">Death Run 3D</a>
#         by
#         <a href="/users/63f050601f76dd27dab35d34/KrispyKreme" rel="nofollow" target="_blank">KrispyKreme</a>
# </div>
# </div>
# </div>
# <div class="footer-links-box"><div class="social-link-box">
# <div class="help-us-improve-box">
# <div class="label-uppercase">
#       Help us improve
#     </div>
# <a class="translate-report" href="/contact/new" rel="nofollow">Bad translation?</a>
# </div>
# <div class="label-uppercase">
#     Social
#   </div>
# <div class="twitter-widget social-widget">
# <a class="twitter-follow-button" href="https://twitter.com/y8_com" rel="noreferrer nofollow" target="_blank">
#     Follow us
#   </a>
# </div>
# <div class="instagram-widget social-widget">
# <a class="instagram-follow-button" href="https://www.instagram.com/y8.games/" rel="noreferrer nofollow" target="_blank"></a>
# </div>
# <div class="facebook-widget social-widget">
# <a class="facebook-follow-button" href="https://www.facebook.com/Y8-Games-225100494185683/" rel="noreferrer nofollow" target="_blank">
#     Follow us
#   </a>
# </div>
# </div>
# <ul class="nav nav-sidebar others">
# <li><a href="/upload">Upload</a></li>
# <li><a href="/games_for_your_website" rel="nofollow">Game Publishers</a></li>
# <li><a href="/studios" rel="nofollow">Game Studios</a></li>
# <li><a href="/download-app" rel="nofollow">Download App</a></li>
# <li><form action="/privacy" class="link-to-form" method="get"><input name="commit" type="submit" value="Privacy Policy"/></form></li>
# <li><form action="/cookie-policy" class="link-to-form" method="get"><input name="commit" type="submit" value="Cookie Policy"/></form></li>
# <li><form action="https://www.y8.com/terms" class="link-to-form" method="get"><input name="commit" type="submit" value="Terms of Use"/></form></li>
# <li><a href="https://blog.y8.com/">Blog</a></li>
# <li><a href="https://forum.y8.com">Forum</a></li>
# <li style="background-image: none;"><a href="/revshare" rel="nofollow">Game Developers</a></li>
# </ul>
# </div>
# <!-- END OF :  DO NOT CHANGE THIS, NEITHER IT'S CONTENT -->
# </div>
# </div><!--
# --><div class="waiting-idnet">
# <div id="user_not_logged_in" style="display:none;">
# <button class="fake-button fake-button-red idnet-fast-register-link" type="button">
#                   Register
#                 </button><!--
# --><button class="fake-button idnet-fast-login-link" type="button">
#                   Log in
#                 </button>
# </div>
# <div id="user_logged_in" style="display:none;">
# <div class="fake-button js-top-menu user-toggle" data-menu="account"></div>
# <div class="links-container-container">
# <div class="links-container sub-menu" style="display:none;">
# <div class="sub-menu-header">
# <span class="username username_box">
#                         My Profile
#                       </span>
# <span class="js-user-idnet-points"></span>
# <span class="points">points</span>
# </div>
# <ul>
# <li>
# <a class="account-menu-link" href="#" id="account-menu-link-profile">My Profile</a>
# </li>
# <li>
# <a class="account-menu-link" href="#" id="account-menu-link-edit-profile" target="blank">Edit Profile</a>
# </li>
# <li>
# <a class="account-menu-link" href="#" id="account-menu-link-games">
#                           Favorites
#                           (<span class="js-favorites-count"></span>)
# </a> </li>
# <li>
# <a class="account-menu-link" destination="/profile/played_games" href="#" id="account-menu-link-visited">
#                           Played Games
# </a> </li>
# <li>
# <a class="account-menu-link" destination="/profile/revenue_share" href="#" id="account-menu-link-my-revenue" style="display: none;">
#                           My Revenue
# </a> </li>
# <li>
# <a class="account-menu-link" destination="/my-studio/my-studio-slug" href="#" id="account-menu-link-see-my-studio" style="display: none;">
#                           See my studio
# </a> </li>
# <li>
# <a class="account-menu-link" destination="/my-studio/my-studio-slug/edit" href="#" id="account-menu-link-edit-my-studio" style="display: none;">
#                           Edit my studio
# </a> </li>
# </ul>
# <div class="sub-menu-footer">
# <ul>
# <li>
# <a class="account-menu-link logout" href="#" style="margin:0;">Log out</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div><!--
# --><div class="fake-button parental-control">
# <div class="js-top-menu parental-control-link" data-menu="parental"></div>
# <a class="parental-control-link-hidden" data-remote="true" href="/parental_filters/new" rel="nofollow"></a>
# </div><!--
# --><div class="parental-filter-form sub-menu" id="parental-filter-form"></div><!--
# --><div class="locale-selector-dropdown fake-button" id="locale-selector-dropdown">
# <ul>
# <li>
# <a aria-label="Language selector" class="en locale-chooser js-top-menu" data-menu="locale" href="#">
# <div class="flag en"> </div>
# <div class="locale-name">English</div>
# </a></li>
# </ul>
# <div class="locales-container-container locales-container sub-menu">
# <ul>
# <li>
# <a aria-label="Language selector" class="en locale-link" href="https://www.y8.com">
# <div class="flag en"> </div>
# <div class="locale-name">English</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="ru locale-link" href="https://ru.y8.com">
# <div class="flag ru"> </div>
# <div class="locale-name">Руcский</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="fr locale-link" href="https://fr.y8.com">
# <div class="flag fr"> </div>
# <div class="locale-name">Français</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="de locale-link" href="https://de.y8.com">
# <div class="flag de"> </div>
# <div class="locale-name">Deutsch</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="it locale-link" href="https://it.y8.com">
# <div class="flag it"> </div>
# <div class="locale-name">Italiano</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="el locale-link" href="https://el.y8.com">
# <div class="flag el"> </div>
# <div class="locale-name">Ελληνικά</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="he locale-link" href="https://he.y8.com">
# <div class="flag he"> </div>
# <div class="locale-name">עברית</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="hi locale-link" href="https://hi.y8.com">
# <div class="flag hi"> </div>
# <div class="locale-name">हिंदी</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="ro locale-link" href="https://ro.y8.com">
# <div class="flag ro"> </div>
# <div class="locale-name">Română</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="es locale-link" href="https://es.y8.com">
# <div class="flag es"> </div>
# <div class="locale-name">Español</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="tl locale-link" href="https://tl.y8.com">
# <div class="flag tl"> </div>
# <div class="locale-name">Tagalog</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="th locale-link" href="https://th.y8.com">
# <div class="flag th"> </div>
# <div class="locale-name">ไทย</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="zh locale-link" href="https://zh.y8.com">
# <div class="flag zh"> </div>
# <div class="locale-name">中文</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="nl locale-link" href="https://nl.y8.com">
# <div class="flag nl"> </div>
# <div class="locale-name">Nederlands</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="vi locale-link" href="https://vi.y8.com">
# <div class="flag vi"> </div>
# <div class="locale-name">Việt</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="tr locale-link" href="https://tr.y8.com">
# <div class="flag tr"> </div>
# <div class="locale-name">Türkçe</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="pt locale-link" href="https://pt.y8.com">
# <div class="flag pt"> </div>
# <div class="locale-name">Português</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="pl locale-link" href="https://pl.y8.com">
# <div class="flag pl"> </div>
# <div class="locale-name">Polski</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="ko locale-link" href="https://ko.y8.com">
# <div class="flag ko"> </div>
# <div class="locale-name">한국어</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="ja locale-link" href="https://ja.y8.com">
# <div class="flag ja"> </div>
# <div class="locale-name">日本語</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="id locale-link" href="https://id.y8.com">
# <div class="flag id"> </div>
# <div class="locale-name">Indonesia</div>
# </a></li>
# <li>
# <a aria-label="Language selector" class="ar locale-link" href="https://ar.y8.com">
# <div class="flag ar"> </div>
# <div class="locale-name">العربية</div>
# </a></li>
# </ul>
# </div>
# </div>
# <div class="mobile-header-block">
# <div class="games-videos-switch game">
# <a href="https://www.y8.com/anim">
# <div class="games-link">games</div>
# <div class="videos-link">videos</div>
# </a>
# </div>
# <div class="popular-newest-games-links">
# <a class="games-link new-game fake-button" href="/new/games" title="Y8 Games : Free online games at Y8.com">New Games</a>
# <a class="games-link pop-game fake-button" href="/games/best" title="Y8 Games : Free online games at Y8.com">Most Popular Games</a>
# </div>
# </div>
# </div>
# </div>
# <div class="flash-messages-box" id="flash-messages-box">
# <div class="flash-notice">
# <div class="container">
# <div class="flash" id="flash-notice"></div>
# <div class="close">×</div>
# </div>
# </div>
# <div class="flash-alert">
# <div class="container">
# <div class="flash flash-alert" id="flash-alert"></div>
# <div class="close">×</div>
# </div>
# </div>
# </div>
# </nav>
# <div class="container">
# <div class="main tag">
# <div class="box items-grid no-background">
# <div class="row" style="margin-bottom: 0;">
# <div class="col-md-12">
# <div class="two-cols two-cols--items-center">
# <div class="bread-crumb">
# <a href="/categories/action_adventure" title="Top Free Online Games tagged Action &amp; Adventure 🎬 - Y8.com">
# <img alt="left angle" src="https://img.y8.com/assets/svg/left-chevron-a49fdff37e89401ab8b4dcb6d23f5109e8e76084ce0fd5277a266f7d24d1c364.svg"/>
#                 Action &amp; Adventure
# </a> </div>
# <a class="button button--xs button--grey" href="/tags">See all tags</a>
# </div>
# <div class="meta-description-text">
# <h1 class="with-description header-5">
#               Top Free Online Games tagged Action
#             </h1>
# <h2 class="text-regular">
#               Play action games at Y8.com. If you need games that have perpetual movement and a lot of fight scenes, the action category is right for you. There is never a dull moment when enemies are always after you, fight them off to reach the next level.
#             </h2>
# </div>
# <div class="sub-title">
# <div class="left">
# <a class="active" href="/tags/action" rel="nofollow" title="Top Free Online Games Tagged Action 🗡 - Y8.COM">
# <h3>
#                 All
#                 Top Free Online Games tagged Action
#                 <span>(671)</span>
# </h3>
# </a>
# <a href="/tags/action/multiplayer" rel="nofollow" title="Top Free Online Games Tagged Action 🗡 - Y8.COM">
#               Multiplayer
#               <span>(64)</span>
# </a>
# <a href="/tags/action/y8_account" rel="nofollow" title="Top Free Online Games Tagged Action 🗡 - Y8.COM">
#               Y8 Games
#               <span>(129)</span>
# </a> </div>
# <div class="sort-by"><span>Sort by:</span><select class="form-control" id="sort" name="sort"><option value="popularity">Popularity</option>
# <option value="rating">Rating</option>
# <option value="date">Date</option></select></div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="items-container" data-base-url="/tags/action" data-max-page="11" id="items_container">
# <div class="item thumb videobox grid-column" data-item-id="213001" data-label-ids="1 Player,3D,Blood,Fighting,Killing Games,Ninja,Samurai,Unity3D,Violence,WebGL,Adventure,Sword,Action,Mouse Skill" data-mp4-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/171895/c6e6962cb822cac30b73f95bfe71c0927a26d0d0.mp4?1667804937" data-ogv-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/171895/36874ee39fa2fde92495fe1a4b1628170eed8800.ogv?1667804937" data-poster-url="https://img.y8.com/assets/video_loader_180x135-63697df7850db644b0fe994bd8a23977d297e8e22941cb82c831a334ec57745a.gif" data-technologies='["unity_webgl"]' data-thumb-movie='["https://img.y8.com/cloud/v2-y8-video-previews-001/videos/171895/958a7942f65566f09beb33c9d621c3cfe7b61e21.gif?1667804937","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/171895/5f6922ac32811551dd74ddcb240f9ae9225f8cef.gif?1667804937","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/171895/a1c36aa25b7d2754e653bc9d35a23acd7d63ab6b.gif?1667804937","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/171895/8a7d1b1549927cbf2bf9c3462ebf912fe733dfcf.gif?1667804937"]' data-vp8-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/171895/c27c33dd24ddde3e2104bf4da64a339c433026ff.webm?1667804937" id="item_213001">
# <a href="https://www.y8.com/games/mini_samurai_kurofune" title="Mini Samurai: Kurofune Game - Play online at Y8.com">
# <input id="for-girls-213001" name="for-girls-213001" type="hidden" value="false"/>
# <div class="item__thumbarea">
# <div class="item__microthumb"></div>
# <div class="item__img-container">
# <img alt="Mini Samurai: Kurofune - Fighting - Y8.COM" class="thumb lazy playable" data-src="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/157367/small.gif" data-srcset="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/157367/small.gif 1x" src="..."/>
# </div>
# </div>
# <div class="item__infos">
# <h4 class="item__title ltr">Mini Samurai: Kurofune</h4>
# <div class="item__technology">
# <p class="unity_webgl">
#           WebGL
#         </p>
# </div>
# <p class="item__rating">
# <span class="item__number">
#           87%
#         </span>
# </p>
# <p class="item__plays-count">
#           18,018 plays
#       </p>
# </div>
# </a></div>
# <div class="item thumb videobox grid-column" data-item-id="161474" data-label-ids="1 Player,Action,Adventure,Fighting,Fun,HTML5,Kids,Snow,Throwing" data-mp4-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/126526/dcf45f3bb860b25986c9c93fff38074432cc2983.mp4?1541704705" data-ogv-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/126526/c97001ad41d8cc14273a7abe6d842f53d3e31fa1.ogv?1541704705" data-poster-url="https://img.y8.com/assets/video_loader_180x135-63697df7850db644b0fe994bd8a23977d297e8e22941cb82c831a334ec57745a.gif" data-technologies='["html5"]' data-thumb-movie='["https://img.y8.com/cloud/v2-y8-video-previews-001/videos/126526/c6463e5b2d447d21ec91c2e8404f21c0250bde4e.gif?1541704705","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/126526/23122b123be76155beddd475ea8a02a0f0342735.gif?1541704705","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/126526/cd1c9196c3251089cc94cd4b149524dc1e346fa9.gif?1541704705","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/126526/2993d4bea48c25eb2a00630865cdbd9242347d47.gif?1541704705"]' data-vp8-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/126526/d7a9aab0bcea48d64da3449652279f2ad21324a2.webm?1541704705" id="item_161474">
# <a href="https://www.y8.com/games/diary_of_a_wimpy_kid_the_meltdown" title="Diary of a Wimpy Kid: The Meltdown Game - Play online at Y8.com">
# <input id="for-girls-161474" name="for-girls-161474" type="hidden" value="false"/>
# <div class="item__thumbarea">
# <div class="item__microthumb"></div>
# <div class="item__img-container">
# <img alt="Diary of a Wimpy Kid: The Meltdown - Action &amp; Adventure - Y8.COM" class="thumb lazy playable" data-src="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/116730/small.gif" data-srcset="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/116730/small.gif 1x" src="..."/>
# </div>
# </div>
# <div class="item__infos">
# <h4 class="item__title ltr">Diary of a Wimpy Kid: The Meltdown</h4>
# <div class="item__technology">
# <p class="html5">
#           HTML5
#         </p>
# </div>
# <p class="item__rating">
# <span class="item__number">
#           88%
#         </span>
# </p>
# <p class="item__plays-count">
#           116,224 plays
#       </p>
# </div>
# </a></div>
# <div class="item thumb videobox grid-column" data-item-id="160907" data-label-ids="1 Player,Action,Free Game,Gun Games,Puzzle,Shooting,Stick,Thinking,Unity3D,WebGL,Y8 Account,Y8 Achievements,Y8 Save,Adventure,Point &amp; Click" data-mp4-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/126261/45c646c554872e51a3440cee684ae2a809ef4412.mp4?1541431363" data-ogv-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/126261
h4>
# <div class="item__technology">
# <p class="unity_webgl">
#           WebGL
#         </p>
# </div>
# <p class="item__rating">
# <span class="item__number">
#           80%
#         </span>
# </p>
# <p class="item__plays-count">
#           8,857 plays
#       </p>
# </div>
# </a></div>
# ...
# </script>
# </div>
# <div class="header-menu-modal" style="display:none"></div>
# <footer class="footer">
# <div class="container">
# <div class="tag-text-container action">
# <div class="h1&gt;">Action Games</div>
# <p>These games emphasize overcoming challenges using physical means like response time and aiming challenges.  By definition, arcade games helped define the action category. Space Invaders (1978) popularized the projectile shooter type of game. The success of early arcade cabinet games generated what later became the video game industry.  As a primary category to video games, the action games subgenre covers many other related game genres like the following list.</p>
# <ul>
# <li><a href="https://www.y8.com/tags/shoot_em_up">Shoot em Up Games</a></li>
# <li><a href="https://www.y8.com/tags/reflexion">Reflex Games</a></li>
# <li><a href="https://www.y8.com/tags/platforms">Platform Games</a></li>
# <li><a href="https://www.y8.com/tags/real_time">Real-time Strategy</a></li>
# <li><a href="https://www.y8.com/tags/zombies">Zombie Games</a></li>
# <li><a href="https://www.y8.com/tags/arcade">Arcade Games</a></li>
# </ul>
# <p>A typical action game will set the player in a scene where they control one or more characters. The goal is to navigate levels, often <a href="https://www.y8.com/tags/collecting_games">collecting things</a>, <a href="https://www.y8.com/tags/obstacle">avoiding obstacles</a>, and of course battling enemies. The primary focus often centers around fighting or shooting. This could be a melee street battle or a medieval cold metal situation. <a href="https://www.y8.com/tags/guns">Firearms</a> and other <a href="https://www.y8.com/tags/canon">projectiles</a> make interesting game objects, even more so given <a href="https://www.y8.com/tags/multiplayer">multiplayer</a> game modes. In single-player action games, levels typically might even with boss fights. When the player's character is hit by enemies, their life will be depleted and without multiple lives, it may be game over.</p>
# </div>
# <div class="bottom-section">
# <div class="logo-container">
# <a aria-label="logo" class="no-event" href="https://www.y8.com/"><img alt="Y8.com" height="30" src="https://img.y8.com/assets/y8/header-logo-b39e5071cb111465fc5a5aef6496121adfcb414692d067f967434d9d80418afc.svg" width="67"/>
# </a>
# <span>© 2006 - 2023 Y8.COM.</span>
# <span>All rights reserved.</span>
# </div>
# <div class="menu-games">
# <div class="title">
#           Y8 Games
#         </div>
# <ul>
# <li><a href="/new/games" title="Y8 Games : Free online games at Y8.com">New Games</a></li>
# <li><a href="/upload" rel="nofollow" title="Upload Your Content to Y8">Upload</a></li>
# <li><a href="/games/best" rel="nofollow" title="Y8 Games : Free online games at Y8.com">Best of New</a></li>
# <li><a href="https://www.y8.com/popular/games" rel="nofollow" title="Y8 Games : Free online games at Y8.com">Most Popular</a></li>
# <li><a href="/download-app" rel="nofollow" title="Download Y8 Browser">Download App</a></li>
# </ul>
# </div>
# <div class="menu-updates">
# <div class="title">
#           Updates
#         </div>
# <ul>
# <li><a href="https://blog.y8.com/" title="Blog">Blog</a></li>
# <li><a href="https://forum.y8.com" title="Forum">Forum</a></li>
# <li><a href="https://twitter.com/y8_com" rel="noreferrer nofollow" target="_blank" title="Twitter">Twitter</a></li>
# <li><a href="https://www.facebook.com/Y8-Games-225100494185683/" rel="noreferrer nofollow" target="_blank" title="Facebook">Facebook</a></li>
# <li><a href="https://www.instagram.com/y8.games/" rel="noreferrer nofollow" target="_blank" title="Instagram">Instagram</a></li>
# <li><a href="https://discord.gg/ba9yXhj" rel="noreferrer nofollow" target="_blank" title="Discord">Discord</a></li>
# </ul>
# </div>
# <div class="menu-company">
# <div class="title">
#           Company
#         </div>
# <ul>
# <li><form action="/terms" class="link-to-form" method="get"><input name="commit" type="submit" value="Terms of Use"/></form></li>
# <li><form action="/privacy" class="link-to-form" method="get"><input name="commit" type="submit" value="Privacy Policy"/></form></li>
# <li><form action="/cookie-policy" class="link-to-form" method="get"><input name="commit" type="submit" value="Cookie Policy"/></form></li>
# <li><a href="/games_for_your_website" rel="nofollow" title="Game Publishers">Game Publishers</a></li>
# <li><a href="/revshare" rel="nofollow" title="Game Developers">Game Developers</a></li>
# <li><form action="/contact/new" class="link-to-form" method="get"><input name="commit" type="submit" value="Contact Form"/></form></li>
# <li><a href="mailto:y8@webgroup-limited.com" rel="noreferrer nofollow" target="_blank">
#             Email Us
#         </a></li>
# </ul>
# </div>
# <div class="follow-us">
# <div class="title">
#           Follow us
#         </div>
# <ul>
# <li>
# <a aria-label="twitter" href="https://twitter.com/y8_com" rel="noreferrer nofollow" target="_blank" title="Twitter">
# <img alt="twitter" height="14" src="https://img.y8.com/assets/svg/twitter-40437c6680e014b927c22e09bae7da5f3317948f71fae4e5daee25eb20c63176.svg" width="18"/>
# </a>
# </li>
# <li>
# <a aria-label="facebook" href="https://www.facebook.com/Y8-Games-225100494185683/" rel="noreferrer nofollow" target="_blank" title="Facebook">
# <img alt="facebook" height="18" src="https://img.y8.com/assets/svg/facebook-807ac7b9c731fd2695350e3c8bf65954582dfeacf87bd8a73ab38e0153543daf.svg" width="18"/>
# </a>
# </li>
# <li>
# <a aria-label="instagram" href="https://www.instagram.com/y8.games/" rel="noreferrer nofollow" target="_blank" title="Instagram">
# <img alt="instagram" height="18" src="https://img.y8.com/assets/svg/instagram-270989005465900b957b5c234169591ea33e43d5f12a3fd7131f486cf6577cfc.svg" width="18"/>
# </a>
# </li>
# <li>
# <a aria-label="discord" href="https://discord.gg/ba9yXhj" rel="noreferrer nofollow" target="_blank" title="Discord">
# <img alt="discord" height="14" src="https://img.y8.com/assets/svg/discord-5fbfb24610991c5e17e89bc628ce593d2f4cfa61b1aa2d12ba7e318728caf974.svg" width="18"/>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-image">
# <img alt="footer image" class="lazy" data-src="https://img.y8.com/assets/y8/footer_image2-bf92e248b92a287362e0ecde08f9bfb8c0f4b5b4fd4177fc6f1a89cd56c05511.webp" data-srcset="https://img.y8.com/assets/y8/footer_image1-422cedcbdbcd68bb2fbf253eafac355ee154ba97da9ad3c587d2e2052b8d7821.webp 1x"/>
# </div>
# </div>
# </div>
# </footer>
# <div class="dark-overlay"></div>
# <div class="policy-validation" id="policy-validation" style="display:none;">
# <div class="logo">
# <img alt="Y8.com" height="27" src="https://img.y8.com/assets/y8/header-logo-b39e5071cb111465fc5a5aef6496121adfcb414692d067f967434d9d80418afc.svg" width="59"/>
# </div>
# <div class="content">
#     We use cookies for content recommendations, traffic measurement, and personalized ads. By using this website, you agree to the <a href="https://www.y8.com/privacy" rel="nofollow" target="_blank">Privacy Policy</a> and <a href="https://www.y8.com/cookie-policy" rel="nofollow" target="_blank">Cookie Policy</a>.
#   </div>
# <div class="actions">
# <span class="validate-policy">Got it</span>
# </div>
# </div>
# <script>
# //<![CDATA[
#
#   var triggerSuccess = function(){
#     if (document.location.pathname.match(/^\/login|^\/register/))
#     {
#       window.location.replace('/');
#     }
#     else
#     {
#       window.location.reload(true);
#     };
#   };
#   var triggerFailure = function(){
#     window.location.reload(true);
#   };
#
#   window.idAsyncInit = function(){
#     var query = document.location.search.substring(1);
#     var obj = {}, vars = query.split('&');
#     var pairs, key, val, ln = vars.length, enableTrack = false;
#
#     if (ln > 0) {
#       for (var i = 0; i < ln; i++) {
#         pairs = vars[i].split('=');
#         key = decodeURIComponent(pairs[0]);
#         val = decodeURIComponent(pairs[1]);
#
#         if (key === 'utm_source') {
#           enableTrack = true;
#         }
#
#         obj[key] = val;
#       }
#       enableTrack && ID.track && ID.track(obj);
#     }
#
#     var idnetRedirectUri = document.location.protocol + '//' + document.location.host + '/auth/idnet/callback';
#
#     // Use an Y8 Account event to wait until after init
#     // CF https://doc.y8.com/docs/javascript/the-basics/
#     //
#     ID.Event.subscribe('id.init', function() {
#       // Any other script may listen to that event and wait for Y8 Account
#       // initialization:
#       //
#       //   $(window).on('id.init', function() {
#       //     // some Y8 Account related code
#       //   });
#       //
#       $(window).trigger('id.init');
#
#       // copied from account.y8.com/sdk/scripts.id.js:48
#       // UserAgent.safari() returns 537.36 on my Ubuntu Chrome :/
#       // OPTIMIZE: fix UserAgent library or move this method to an object.
#       function safari() {
#         return navigator.userAgent.indexOf('Safari') != -1 &&
#           navigator.userAgent.indexOf('Chrome') == -1;
#       }
#
#       var idnetOptions = safari() ? { redirect_uri: idnetRedirectUri + '?origin=' + encodeURIComponent(location.pathname + location.search) } : {};
#
#       $('.idnet-fast-login-link').on('click', function(){
#         // Y8 Account tests if the browser is Safari.
#         // If no: usual login approach, using the modal
#         // If yes: OAuth recommended approach, redirecting the client
#         //
#         // Because Safari does not allow cross-domain cookies.
#         //
#         // Also, this is not the default Y8 Account behavior because we don't want
#         // to break the user experience and end a game session by redirecting
#         // the user. This is why the choice if up to the client (using regular
#         // ID.login() or ID.safariFixLogin() method).
#         //
#         ID.safariFixLogin(null, idnetOptions);
#         _gaq.push (['_trackEvent', 'Authentication', 'login']);
#         $(document).trigger('checkOverlayMenus');
#       });
#       $('.idnet-fast-register-link').on('click', function(){
#         ID.safariFixRegister(null, idnetOptions);
#         _gaq.push (['_trackEvent', 'Authentication', 'register']);
#         $(document).trigger('checkOverlayMenus');
#       });
#     });
#
#     ID.Event.subscribe('auth.authResponseChange', function(auth) {
#       $(window).trigger('auth.authResponseChange');
#     });
#
#     ID.init({
#      appId: '4fbb62b133968d57c10041b0',
#      redirectUri: idnetRedirectUri,
#      responseType: 'code'
#     });
#   };
#   (function () {
#     var idnet = document.createElement('script');
#     idnet.type = 'text/javascript';
#     idnet.async = true;
#     idnet.sucess = triggerSuccess;
#     idnet.error = triggerFailure;
#     idnet.src = 'https://cdn.y8.com/api/sdk.js';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(idnet, s);
#   })();
#
# //]]>
# </script>
# <script id="live-search-template" type="text/x-handlebars-template">
#   <li>
#     <a href="{{path}}">
#       <img src="{{thumbnail}}" class="thumb">
#       {{name}}
#     </a>
#   </li>
# </script>
# <script data-selector="sort-by" defer="defer" id="sort-by-script" src="https://img.y8.com/packs/js/controllers/items/helpers/sort_by-a631768d4a72cf441834.js"></script>
# <script>
# //<![CDATA[
#
#     window.Settings = window.Settings || {};
#     Settings.ga_account = "UA-18828733-1";
#     Settings.ga_domain = ".y8.com";
#     Settings.ga_sample_rate = 10;
#     window.google_analytics_uacct = "UA-18828733-1";
#     window.google_analytics_domain_name = ".y8.com";
#
# //]]>
# </script>
# <script>
# //<![CDATA[
#
#   // initialize google analytics
#   document.addEventListener("DOMContentLoaded", function(event) {
#     window._gaq = window._gaq || [];
#     _gaq.push(['_setAccount', Settings.ga_account]);
#
#     if (Settings.ga_domain) {
#       _gaq.push(['_setDomainName', Settings.ga_domain]);
#     }
#
#     _gaq.push(['_setSampleRate', window.Settings.ga_sample_rate]);
#     _gaq.push(['_trackPageview']);
#
#       // insert google analytics lib
#       var ga = document.createElement('script');
#       ga.type = 'text/javascript';
#       ga.async = true;
#       ga.src = ('https:' == window.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(ga, s);
#   });
#
# //]]>
# </script>
# <!-- Yandex.Metrika counter -->
# <script>
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter = new Ya.Metrika({
#                     id:45364173,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true,
#                     webvisor:true,
#                     trackHash:true
#                 });
#
#                 var sessionParams = {
#                     user_status: Cookies.get('logged_in') ? 'member' : 'guest',
#                     os64bit: OSDetector.bit64.toString(),
#                     ad_block_ext: window.adBlockDetected,
#
#                 };
#
#                 w.yaCounter.params(sessionParams);
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/45364173" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# </body>
# </html>
# <!-- 2023-03-12 08:03:46 UTC -->

# %% [markdown]
# ### Extract Name, Technology, Ratings and Players from the Games

# %% [markdown]
# #### To find related `div`, `h`, `p`, `span`, `class` Select the Game  and Right-Click on the `Inspect`
#
# ![img1](https://i.imgur.com/QeYBSND.jpg)
# ![img2](https://i.imgur.com/kW9b6hk.jpg)

# %%
div_tags = doc.find_all('div',class_='item thumb videobox grid-column')

# %%
div_tags
# Out:
# [<div class="item thumb videobox grid-column" data-item-id="68221" data-label-ids="1 Player,3D,Free Game,Default,Unity3D,Blocks,Adventure,Undead,Voxel,WebGL,Zombies,Mine" data-mp4-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/e43eeeeefaf81f9ac5785e0d7e4d62f5fdfe1331.mp4?1554276634" data-ogv-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/5c61f9722448a3e6809f04479e7eca83b1df7050.ogv?1554276634" data-poster-url="https://img.y8.com/assets/video_loader_180x135-63697df7850db644b0fe994bd8a23977d297e8e22941cb82c831a334ec57745a.gif" data-technologies='["unity_webgl","unity_webgl_32_bit"]' data-thumb-movie='["https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/5a65f2a0509c0d2a583cff64e97c37767a91bd29.gif?1554276634","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/d2bd72e81c7006fe8e963986e8aa2c997ac55daa.gif?1554276634","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/05cab884a515c49418159399ce69727417e458c5.gif?1554276634","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/e52d43a912dfc13297323b31f9df7e177877026d.gif?1554276634"]' data-vp8-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/977530394c68171aa759cc7399db8c48763a05ea.webm?1554276634" id="item_68221">
#  <a href="https://www.y8.com/games/mineclone_3" title="Mineclone 3 Game - Play online at Y8.com">
#  <input id="for-girls-68221" name="for-girls-68221" type="hidden" value="false">
#  <div class="item__thumbarea">
#  <div class="item__microthumb"></div>
#  <div class="item__img-container">
#  <img alt="
type="hidden" value="false"/>
#  <div class="item__thumbarea">
#  <div class="item__microthumb"></div>
#  <div class="item__img-container">
#  <img alt="Phineas &amp; Ferb: Transportinators of Doooom - Action &amp; Adventure - Y8.COM" class="thumb lazy playable" data-src="https://img.y8.com/cloud/y8-thumbs/43126/small.jpg" data-srcset="https://img.y8.com/cloud/y8-thumbs/43126/small.jpg 1x" src="..."/>
#  </div>
#  </div>
#  <div class="item__infos">
#  <h4 class="item__title ltr">Phineas &amp; Ferb: Transportinators of Doooom</h4>
#  <div class="item__technology">
#  <p class="unity_player">
#            Unity 3D
#          </p>
#  </div>
#  <p class="item__rating">
#  <span class="item__number">
#            89%
#          </span>
#  </p>
#  <p class="item__plays-count">
#            8,936,768 plays
#        </p>
#  </div>
#  </a></div>,
#  <div class="item thumb videobox grid-column" data-item-id="197031" data-label-ids="Ghost,1 Player,Cartoon,Drawing,Fun,Halloween,HTML5,Mouse Skill,Obstacle,Side Scrolling,Touchscreen,Android only,Mobile" data-mp4-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/158288/d0b36aec47adb6b26579cf092c3a846e5111fa72.mp4?1635047589" data-ogv-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/158288/d012597681b9caae1f855197c756b6957ccab51f.ogv?1635047589" data-poster-url="https://img.y8.com/assets/video_loader_180x135-63697df7850db644b0fe994bd8a23977d297e8e22941cb82c831a334ec57745a.gif" data-technologies='["html5"]' data-thumb-movie='["https://img.y8.com/cloud/v2-y8-video-previews-001/videos/158288/e9952d45ab7e2a39e91ecfb8e48a99ad2349001e.gif?1635047589","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/158288/83e30e64e0274182ffe23d7224ca46e7351a388b.gif?1635047589","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/158288/17530678bc223b17581d3b17a7739dfe789662bf.gif?1635047589","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/158288/6cdacb590896f52e666e564fc26a2ff59598b442.gif?1635047589"]' data-vp8-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/158288/f166cece747c578c220192eb9487dce8899bcd23.webm?1635047589" id="item_197031">
#  <a href="https://www.y8.com/games/scooby-doo_and_guess_who_ghost_creator" title="Scooby-Doo and Guess Who: Ghost Creator Game - Play online at Y8.com">
#  <input id="for-girls-197031" name="for-girls-197031" type="hidden" value="false"/>
#  <div class="item__thumbarea">
#  <div class="item__microthumb"></div>
#  <div class="item__img-container">
#  <img alt="Scooby-Doo and Guess Who: Ghost Creator - Action &amp; Adventure - Y8.COM" class="thumb lazy playable" data-src="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/144884/small.gif" data-srcset="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/144884/small.gif 1x" src="..."/>
#  </div>
#  </div>
#  <div class="item__infos">
#  <h4 class="item__title ltr">Scooby-Doo and Guess Who: Ghost Creator</h4>
#  <div class="item__technology">
#  <p class="html5">
#            HTML5
#          </p>
#  </div>
#  <p class="item__rating">
#  <span class="item__number">
#            78%
#          </span>
#  </p>
#  <p class="item__plays-count">
#            25,199 plays
#        </p>
#  </div>
#  </a></div>,
#  <div class="item thumb videobox grid-column" data-item-id="187505" data-label-ids="1 Player,Action,Killing Games,Shooting,Undead,Unity3D,WebGL,Zombies,Army Games,Blood,Mutant" data-mp4-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/149833/53f70c4541671402242787955d2d03330f116c11.mp4?1608621285" data-ogv-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/149833/1260318362c250bbb22adcd540ded0f676c49204.ogv?1608621285" data-poster-url="https://img.y8.com/assets/video_loader_180x135-63697df7850db644b0fe994bd8a23977d297e8e22941cb82c831a334ec57745a.gif" data-technologies='["unity_webgl"]' data-thumb-movie='["https://img.y8.com/cloud/v2-y8-video-previews-001/videos/149833/fca6b7beb1811ee4e9106d3cee552ce89782f0ed.gif?1608621285","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/149833/3a177b7267ff605f6a811e95052c216d25d6ffc5.gif?1608621285","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/149833/7af47ac083cd6b1f36b81189641ce28d417d6992.gif?1608621285","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/149833/7635a48c2f859a41fcc1a369bff768c667eee229.gif?1608621285"]' data-vp8-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/149833/357f04aa5c727777aea6080fd4d43f2be7f8c183.webm?1608621285" id="item_187505">
#  <a href="https://www.y8.com/games/10-103" title="10-103 Game - Play online at Y8.com">
#  <input id="for-girls-187505" name="for-girls-187505" type="hidden" value="false"/>
#  <div class="item__thumbarea">
#  <div class="item__microthumb"></div>
#  <div class="item__img-container">
#  <img alt="10-103 - Action &amp; Adventure - Y8.COM" class="thumb lazy playable" data-src="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/138408/small.gif" data-srcset="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/138408/small.gif 1x" src="..."/>
#  </div>
#  </div>
#  <div class="item__infos">
#  <h4 class="item__title ltr">10-103</h4>
#  <div class="item__technology">
#  <p class="unity_webgl">
#            WebGL
#          </p>
#  </div>
#  <p class="item__rating">
#  <span class="item__number">
#            91%
#          </span>
#  </p>
#  <p class="item__plays-count">
#            70,354 plays
#        </p>
#  </div>
#  </a></div>]

# %%
len(div_tags)
# Out:
# 64

# %%
abc = div_tags[0]

# %%
abc
# Out:
# <div class="item thumb videobox grid-column" data-item-id="68221" data-label-ids="1 Player,3D,Free Game,Default,Unity3D,Blocks,Adventure,Undead,Voxel,WebGL,Zombies,Mine" data-mp4-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/e43eeeeefaf81f9ac5785e0d7e4d62f5fdfe1331.mp4?1554276634" data-ogv-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/5c61f9722448a3e6809f04479e7eca83b1df7050.ogv?1554276634" data-poster-url="https://img.y8.com/assets/video_loader_180x135-63697df7850db644b0fe994bd8a23977d297e8e22941cb82c831a334ec57745a.gif" data-technologies='["unity_webgl","unity_webgl_32_bit"]' data-thumb-movie='["https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/5a65f2a0509c0d2a583cff64e97c37767a91bd29.gif?1554276634","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/d2bd72e81c7006fe8e963986e8aa2c997ac55daa.gif?1554276634","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/05cab884a515c49418159399ce69727417e458c5.gif?1554276634","https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/e52d43a912dfc13297323b31f9df7e177877026d.gif?1554276634"]' data-vp8-movie="https://img.y8.com/cloud/v2-y8-video-previews-001/videos/130170/977530394c68171aa759cc7399db8c48763a05ea.webm?1554276634" id="item_68221">
# <a href="https://www.y8.com/games/mineclone_3" title="Mineclone 3 Game - Play online at Y8.com">
# <input id="for-girls-68221" name="for-girls-68221" type="hidden" value="false">
# <div class="item__thumbarea">
# <div class="item__microthumb"></div>
# <div class="item__img-container">
# <img alt="Mineclone 3 - Action &amp; Adventure - Y8.COM" class="thumb lazy playable" data-src="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/120478/small.gif" data-srcset="https://img.y8.com/cloud/v2-y8-thumbs-small-thumbnails-001/120478/small.gif 1x" src="..."/>
# </div>
# </div>
# <div class="item__infos">
# <h4 class="item__title ltr">Mineclone 3</h4>
# <div class="item__technology">
# <p class="unity_webgl">
#           WebGL
#         </p>
# </div>
# <p class="item__rating">
# <span class="item__number">
#           78%
#         </span>
# </p>
# <p class="item__plays-count">
#           13,076,707 plays
#       </p>
# </div>
# </input></a></div>

# %% [markdown]
# To represent `Game Name` we can go on with `h4 tag`

# %%
h4_tags = abc.find('h4')

# %%
h4_tags
# Out:
# <h4 class="item__title ltr">Mineclone 3</h4>

# %%
name = h4_tags.text.strip()

# %%
name
# Out:
# 'Mineclone 3'

# %% [markdown]
# To represent `Technology` we can go on with `class = 'item__technology'`

# %%
tech = abc.find('div', class_='item__technology')

# %%
tech
# Out:
# <div class="item__technology">
# <p class="unity_webgl">
#           WebGL
#         </p>
# </div>

# %%
technology = tech.text.strip()

# %%
technology
# Out:
# 'WebGL'

# %% [markdown]
# To represent `Ratings` we can go on with `class = 'item__number'`

# %%
rate = abc.find(class_='item__number')

# %%
rate
# Out:
# <span class="item__number">
#           78%
#         </span>

# %%
ratings = rate.text.strip()

# %%
ratings
# Out:
# '78%'

# %% [markdown]
# To represent `No.of Players` we can go on with `class = 'item__plays-count'`

# %%
play = abc.find('p', class_='item__plays-count')

# %%
play
# Out:
# <p class="item__plays-count">
#           13,076,707 plays
#       </p>

# %%
player = play.text.strip()

# %%
players = player[:-6].replace(',','')

# %%
players
# Out:
# '13076707'

# %% [markdown]
# Now we have to write and define reusable functions from the above cells

# %%
def parse_top_games(abc):
# <div> tag contains Game name, Technology, Ratings, No.of Players   
    h4_tags = abc.find('h4')
# Game name   
    name = h4_tags.text.strip()
#Technology    
    tech = abc.find('div', class_='item__technology')
    technology = tech.text.strip()
#Ratings
    rate = abc.find(class_='item__number')
    ratings = rate.text.strip()
#No.of.Players
    play = abc.find('p', class_='item__plays-count')
    player = play.text.strip()
    players = player[:-6].replace(',','')
#Returning the values in Dict format    
    return {
        
        'Game' : name,
        'Technology' : technology,
        'Ratings' : ratings,
        'Players' : players
    }

# %%
parse_top_games(div_tags[0])
# Out:
# {'Game': 'Mineclone 3',
#  'Technology': 'WebGL',
#  'Ratings': '78%',
#  'Players': '13076707'}

# %%
parse_top_games(div_tags[1])
# Out:
# {'Game': 'Brawl Bash',
#  'Technology': 'WebGL',
#  'Ratings': '77%',
#  'Players': '71009'}

# %% [markdown]
# We have extracted the data in successful manner.

# %% [markdown]
# ### Compile extracted information into lists and dictionaries

# %%
top_games = [parse_top_games(a) for a in div_tags]

# %%
top_games
# Out:
# [{'Game': 'Mineclone 3',
#   'Technology': 'WebGL',
#   'Ratings': '78%',
#   'Players': '13076707'},
#  {'Game': 'Brawl Bash',
#   'Technology': 'WebGL',
#   'Ratings': '77%',
#   'Players': '71009'},
#  {'Game': 'Hard Life',
#   'Technology': 'HTML5',
#   'Ratings': '67%',
#   'Players': '525360'},
#  {'Game': 'The Backrooms',
#   'Technology': 'WebGL',
#   'Ratings': '51%',
#   'Players': '104878'},
#  {'Game': 'Light in the Dark',
#   'Technology': 'HTML5',
#   'Ratings': '76%',
#   'Players': '7623'},
#  {'Game': 'Police Chase Real Cop Driver',
#   'Technology': 'WebGL',
#   'Ratings': '79%',
#   'Players': '1490237'},
#  {'Game': 'Zombie Horde',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '2992'},
#  {'Game': 'Stick Fighter 3D',
#   'Technology': 'WebGL',
#   'Ratings': '69%',
#   'Players': '167090'},
#  {'Game': 'Creepy Evil Granny',
#   'Technology': 'WebGL',
#   'Ratings': '76%',
#   'Players': '78681'},
#  {'Game': 'Kogama: Piggy',
#   'Technology': 'WebGL',
#   'Ratings': '89%',
#   'Players': '11019'},
#  {'Game': 'Stickman Boost!',
#   'Technology': 'HTML5',
#   'Ratings': '72%',
#   'Players': '4979446'},
#  {'Game': 'Fireboy And Watergirl Light Temple',
#   'Technology': 'HTML5',
#   'Ratings': '85%',
#   'Players': '83397838'},
#  {'Game': 'Pants',
#   'Technology': 'HTML5',
#   'Ratings': '91%',
#   'Players': '12725'},
#  {'Game': 'Samurai Warrios',
#   'Technology': 'WebGL',
#   'Ratings': '91%',
#   'Players': '29641'},
#  {'Game': 'Cave Jumper',
#   'Technology': 'WebGL',
#   'Ratings': '77%',
#   'Players': '3190'},
#  {'Game': 'Locoman',
#   'Technology': 'HTML5',
#   'Ratings': '67%',
#   'Players': '3138'},
#  {'Game': 'Castle of Magic',
#   'Technology': 'HTML5',
#   'Ratings': '80%',
#   'Players': '4371'},
#  {'Game': 'Minescrafter: Steve and Alex',
#   'Technology': 'HTML5',
#   'Ratings': '75%',
#   'Players': '18567'},
#  {'Game': "Lick 'em All",
#   'Technology': 'HTML5',
#   'Ratings': '66%',
#   'Players': '1786470'},
#  {'Game': 'Bomb It 6',
#   'Technology': 'HTML5',
#   'Ratings': '88%',
#   'Players': '29547593'},
#  {'Game': 'Chef Quest',
#   'Technology': 'HTML5',
#   'Ratings': '93%',
#   'Players': '1839'},
#  {'Game': 'A Flying Machine',
#   'Technology': 'HTML5',
#   'Ratings': '75%',
#   'Players': '29825'},
#  {'Game': 'Clickventure: Castaway',
#   'Technology': 'WebGL',
#   'Ratings': '80%',
#   'Players': '13015'},
#  {'Game': 'Super Hot',
#   'Technology': 'WebGL',
#   'Ratings': '81%',
#   'Players': '2897474'},
#  {'Game': 'Hall of Palettes',
#   'Technology': 'HTML5',
#   'Ratings': '82%',
#   'Players': '1605'},
#  {'Game': 'Total Darkness',
#   'Technology': 'HTML5',
#   'Ratings': '92%',
#   'Players': '15271'},
#  {'Game': 'Vex 5',
#   'Technology': 'HTML5',
#   'Ratings': '81%',
#   'Players': '847362'},
#  {'Game': 'Trapdoor',
#   'Technology': 'HTML5',
#   'Ratings': '54%',
#   'Players': '699068'},
#  {'Game': 'Impostor',
#   'Technology': 'HTML5',
#   'Ratings': '78%',
#   'Players': '4381048'},
#  {'Game': 'Pixel Challenge',
#   'Technology': 'HTML5',
#   'Ratings': '68%',
#   'Players': '18067'},
#  {'Game': 'Bomb It 4',
#   'Technology': 'HTML5',
#   'Ratings': '87%',
#   'Players': '23802823'},
#  {'Game': 'Monkey Go Happy Stage 481',
#   'Technology': 'HTML5',
#   'Ratings': '71%',
#   'Players': '65482'},
#  {'Game': 'Ascent',
#   'Technology': 'HTML5',
#   'Ratings': '71%',
#   'Players': '5584'},
#  {'Game': "Tom and Jerry: Don't Make A Mess",
#   'Technology': 'HTML5',
#   'Ratings': '89%',
#   'Players': '57464'},
#  {'Game': "Let's Kill Jeff the Killer: The Asylum",
#   'Technology': 'WebGL',
#   'Ratings': '81%',
#   'Players': '48152'},
#  {'Game': 'Steve Ball Temple',
#   'Technology': 'HTML5',
#   'Ratings': '62%',
#   'Players': '1855'},
#  {'Game': 'Spacescape',
#   'Technology': 'HTML5',
#   'Ratings': '67%',
#   'Players': '7839'},
#  {'Game': 'The Caribbean Sea 3D',
#   'Technology': 'WebGL',
#   'Ratings': '83%',
#   'Players': '181494'},
#  {'Game': 'Mom is Gone',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '36966'},
#  {'Game': "We're Imposter",
#   'Technology': 'WebGL',
#   'Ratings': '87%',
#   'Players': '105193'},
#  {'Game': 'Vex 6',
#   'Technology': 'HTML5',
#   'Ratings': '74%',
#   'Players': '365665'},
#  {'Game': 'Rocking Sky Trip',
#   'Technology': 'WebGL',
#   'Ratings': '75%',
#   'Players': '13990176'},
#  {'Game': 'EvoWars io',
#   'Technology': 'HTML5',
#   'Ratings': '77%',
#   'Players': '41890898'},
#  {'Game': 'Moon Battle Royale',
#   'Technology': 'WebGL',
#   'Ratings': '73%',
#   'Players': '44693'},
#  {'Game': 'Animal Crackers',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '4985'},
#  {'Game': 'Hero 2: Super Kick',
#   'Technology': 'WebGL',
#   'Ratings': '81%',
#   'Players': '641920'},
#  {'Game': 'Dino Rush',
#   'Technology': 'WebGL',
#   'Ratings': '93%',
#   'Players': '2903'},
#  {'Game': 'Mike & Munk',
#   'Technology': 'HTML5',
#   'Ratings': '82%',
#   'Players': '9837'},
#  {'Game': 'The Railroad to Elsewhere',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '16480'},
#  {'Game': 'Long Live the King!',
#   'Technology': 'WebGL',
#   'Ratings': '86%',
#   'Players': '12131'},
#  {'Game': 'Brave Explorers',
#   'Technology': 'HTML5',
#   'Ratings': '94%',
#   'Players': '6066'},
#  {'Game': 'Grandpa Run 3D',
#   'Technology': 'WebGL',
#   'Ratings': '85%',
#   'Players': '12892364'},
#  {'Game': 'Nenetl',
#   'Technology': 'WebGL',
#   'Ratings': '73%',
#   'Players': '1660'},
#  {'Game': 'Rorty',
#   'Technology': 'HTML5',
#   'Ratings': '83%',
#   'Players': '13241'},
#  {'Game': 'The Grand Escape of Dielucard',
#   'Technology': 'WebGL',
#   'Ratings': '73%',
#   'Players': '8585'},
#  {'Game': 'Error#54',
#   'Technology': 'WebGL',
#   'Ratings': '74%',
#   'Players': '1228951'},
#  {'Game': 'StarCatcher',
#   'Technology': 'HTML5',
#   'Ratings': '80%',
#   'Players': '2741'},
#  {'Game': 'Cube Craft Survival',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '19866'},
#  {'Game': 'Police Cop Driver Simulator',
#   'Technology': 'WebGL',
#   'Ratings': '79%',
#   'Players': '255957'},
#  {'Game': 'Bad Ben',
#   'Technology': 'WebGL',
#   'Ratings': '79%',
#   'Players': '95989'},
#  {'Game': 'Vex 4',
#   'Technology': 'HTML5',
#   'Ratings': '81%',
#   'Players': '2753991'},
#  {'Game': 'Phineas & Ferb: Transportinators of Doooom',
#   'Technology': 'Unity 3D',
#   'Ratings': '89%',
#   'Players': '8936768'},
#  {'Game': 'Scooby-Doo and Guess Who: Ghost Creator',
#   'Technology': 'HTML5',
#   'Ratings': '78%',
#   'Players': '25199'},
#  {'Game': '10-103',
#   'Technology': 'WebGL',
#   'Ratings': '91%',
#   'Players': '70354'}]

# %% [markdown]
# This is the list of data for a particular page with url `action`
#
# Now we have to define a reusable function to print list of games data by refering the above cells.

# %%
def get_top_games(doc):
    div_tags = doc.find_all('div', class_='item thumb videobox grid-column')
    top_games = [parse_top_games(a) for a in div_tags]
    return top_games

# %%
top_games
# Out:
# [{'Game': 'Mineclone 3',
#   'Technology': 'WebGL',
#   'Ratings': '78%',
#   'Players': '13076707'},
#  {'Game': 'Brawl Bash',
#   'Technology': 'WebGL',
#   'Ratings': '77%',
#   'Players': '71009'},
#  {'Game': 'Hard Life',
#   'Technology': 'HTML5',
#   'Ratings': '67%',
#   'Players': '525360'},
#  {'Game': 'The Backrooms',
#   'Technology': 'WebGL',
#   'Ratings': '51%',
#   'Players': '104878'},
#  {'Game': 'Light in the Dark',
#   'Technology': 'HTML5',
#   'Ratings': '76%',
#   'Players': '7623'},
#  {'Game': 'Police Chase Real Cop Driver',
#   'Technology': 'WebGL',
#   'Ratings': '79%',
#   'Players': '1490237'},
#  {'Game': 'Zombie Horde',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '2992'},
#  {'Game': 'Stick Fighter 3D',
#   'Technology': 'WebGL',
#   'Ratings': '69%',
#   'Players': '167090'},
#  {'Game': 'Creepy Evil Granny',
#   'Technology': 'WebGL',
#   'Ratings': '76%',
#   'Players': '78681'},
#  {'Game': 'Kogama: Piggy',
#   'Technology': 'WebGL',
#   'Ratings': '89%',
#   'Players': '11019'},
#  {'Game': 'Stickman Boost!',
#   'Technology': 'HTML5',
#   'Ratings': '72%',
#   'Players': '4979446'},
#  {'Game': 'Fireboy And Watergirl Light Temple',
#   'Technology': 'HTML5',
#   'Ratings': '85%',
#   'Players': '83397838'},
#  {'Game': 'Pants',
#   'Technology': 'HTML5',
#   'Ratings': '91%',
#   'Players': '12725'},
#  {'Game': 'Samurai Warrios',
#   'Technology': 'WebGL',
#   'Ratings': '91%',
#   'Players': '29641'},
#  {'Game': 'Cave Jumper',
#   'Technology': 'WebGL',
#   'Ratings': '77%',
#   'Players': '3190'},
#  {'Game': 'Locoman',
#   'Technology': 'HTML5',
#   'Ratings': '67%',
#   'Players': '3138'},
#  {'Game': 'Castle of Magic',
#   'Technology': 'HTML5',
#   'Ratings': '80%',
#   'Players': '4371'},
#  {'Game': 'Minescrafter: Steve and Alex',
#   'Technology': 'HTML5',
#   'Ratings': '75%',
#   'Players': '18567'},
#  {'Game': "Lick 'em All",
#   'Technology': 'HTML5',
#   'Ratings': '66%',
#   'Players': '1786470'},
#  {'Game': 'Bomb It 6',
#   'Technology': 'HTML5',
#   'Ratings': '88%',
#   'Players': '29547593'},
#  {'Game': 'Chef Quest',
#   'Technology': 'HTML5',
#   'Ratings': '93%',
#   'Players': '1839'},
#  {'Game': 'A Flying Machine',
#   'Technology': 'HTML5',
#   'Ratings': '75%',
#   'Players': '29825'},
#  {'Game': 'Clickventure: Castaway',
#   'Technology': 'WebGL',
#   'Ratings': '80%',
#   'Players': '13015'},
#  {'Game': 'Super Hot',
#   'Technology': 'WebGL',
#   'Ratings': '81%',
#   'Players': '2897474'},
#  {'Game': 'Hall of Palettes',
#   'Technology': 'HTML5',
#   'Ratings': '82%',
#   'Players': '1605'},
#  {'Game': 'Total Darkness',
#   'Technology': 'HTML5',
#   'Ratings': '92%',
#   'Players': '15271'},
#  {'Game': 'Vex 5',
#   'Technology': 'HTML5',
#   'Ratings': '81%',
#   'Players': '847362'},
#  {'Game': 'Trapdoor',
#   'Technology': 'HTML5',
#   'Ratings': '54%',
#   'Players': '699068'},
#  {'Game': 'Impostor',
#   'Technology': 'HTML5',
#   'Ratings': '78%',
#   'Players': '4381048'},
#  {'Game': 'Pixel Challenge',
#   'Technology': 'HTML5',
#   'Ratings': '68%',
#   'Players': '18067'},
#  {'Game': 'Bomb It 4',
#   'Technology': 'HTML5',
#   'Ratings': '87%',
#   'Players': '23802823'},
#  {'Game': 'Monkey Go Happy Stage 481',
#   'Technology': 'HTML5',
#   'Ratings': '71%',
#   'Players': '65482'},
#  {'Game': 'Ascent',
#   'Technology': 'HTML5',
#   'Ratings': '71%',
#   'Players': '5584'},
#  {'Game': "Tom and Jerry: Don't Make A Mess",
#   'Technology': 'HTML5',
#   'Ratings': '89%',
#   'Players': '57464'},
#  {'Game': "Let's Kill Jeff the Killer: The Asylum",
#   'Technology': 'WebGL',
#   'Ratings': '81%',
#   'Players': '48152'},
#  {'Game': 'Steve Ball Temple',
#   'Technology': 'HTML5',
#   'Ratings': '62%',
#   'Players': '1855'},
#  {'Game': 'Spacescape',
#   'Technology': 'HTML5',
#   'Ratings': '67%',
#   'Players': '7839'},
#  {'Game': 'The Caribbean Sea 3D',
#   'Technology': 'WebGL',
#   'Ratings': '83%',
#   'Players': '181494'},
#  {'Game': 'Mom is Gone',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '36966'},
#  {'Game': "We're Imposter",
#   'Technology': 'WebGL',
#   'Ratings': '87%',
#   'Players': '105193'},
#  {'Game': 'Vex 6',
#   'Technology': 'HTML5',
#   'Ratings': '74%',
#   'Players': '365665'},
#  {'Game': 'Rocking Sky Trip',
#   'Technology': 'WebGL',
#   'Ratings': '75%',
#   'Players': '13990176'},
#  {'Game': 'EvoWars io',
#   'Technology': 'HTML5',
#   'Ratings': '77%',
#   'Players': '41890898'},
#  {'Game': 'Moon Battle Royale',
#   'Technology': 'WebGL',
#   'Ratings': '73%',
#   'Players': '44693'},
#  {'Game': 'Animal Crackers',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '4985'},
#  {'Game': 'Hero 2: Super Kick',
#   'Technology': 'WebGL',
#   'Ratings': '81%',
#   'Players': '641920'},
#  {'Game': 'Dino Rush',
#   'Technology': 'WebGL',
#   'Ratings': '93%',
#   'Players': '2903'},
#  {'Game': 'Mike & Munk',
#   'Technology': 'HTML5',
#   'Ratings': '82%',
#   'Players': '9837'},
#  {'Game': 'The Railroad to Elsewhere',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '16480'},
#  {'Game': 'Long Live the King!',
#   'Technology': 'WebGL',
#   'Ratings': '86%',
#   'Players': '12131'},
#  {'Game': 'Brave Explorers',
#   'Technology': 'HTML5',
#   'Ratings': '94%',
#   'Players': '6066'},
#  {'Game': 'Grandpa Run 3D',
#   'Technology': 'WebGL',
#   'Ratings': '85%',
#   'Players': '12892364'},
#  {'Game': 'Nenetl',
#   'Technology': 'WebGL',
#   'Ratings': '73%',
#   'Players': '1660'},
#  {'Game': 'Rorty',
#   'Technology': 'HTML5',
#   'Ratings': '83%',
#   'Players': '13241'},
#  {'Game': 'The Grand Escape of Dielucard',
#   'Technology': 'WebGL',
#   'Ratings': '73%',
#   'Players': '8585'},
#  {'Game': 'Error#54',
#   'Technology': 'WebGL',
#   'Ratings': '74%',
#   'Players': '1228951'},
#  {'Game': 'StarCatcher',
#   'Technology': 'HTML5',
#   'Ratings': '80%',
#   'Players': '2741'},
#  {'Game': 'Cube Craft Survival',
#   'Technology': 'WebGL',
#   'Ratings': '88%',
#   'Players': '19866'},
#  {'Game': 'Police Cop Driver Simulator',
#   'Technology': 'WebGL',
#   'Ratings': '79%',
#   'Players': '255957'},
#  {'Game': 'Bad Ben',
#   'Technology': 'WebGL',
#   'Ratings': '79%',
#   'Players': '95989'},
#  {'Game': 'Vex 4',
#   'Technology': 'HTML5',
#   'Ratings': '81%',
#   'Players': '2753991'},
#  {'Game': 'Phineas & Ferb: Transportinators of Doooom',
#   'Technology': 'Unity 3D',
#   'Ratings': '89%',
#   'Players': '8936768'},
#  {'Game': 'Scooby-Doo and Guess Who: Ghost Creator',
#   'Technology': 'HTML5',
#   'Ratings': '78%',
#   'Players': '25199'},
#  {'Game': '10-103',
#   'Technology': 'WebGL',
#   'Ratings': '91%',
#   'Players': '70354'}]

# %%
topic_page_xyz = get_topic_page('action')
top_games_xyz = get_top_games(topic_page_xyz)
top_games_xyz[:5]
# Out:
# [{'Game': 'Mini Samurai: Kurofune',
#   'Technology': 'WebGL',
#   'Ratings': '87%',
#   'Players': '18023'},
#  {'Game': 'Diary of a Wimpy Kid: The Meltdown',
#   'Technology': 'HTML5',
#   'Ratings': '88%',
#   'Players': '116225'},
#  {'Game': 'Stained Act 1',
#   'Technology': 'WebGL',
#   'Ratings': '81%',
#   'Players': '137812'},
#  {'Game': 'LA Shark',
#   'Technology': 'WebGL',
#   'Ratings': '76%',
#   'Players': '1454426'},
#  {'Game': 'Madness: Off-Color',
#   'Technology': 'HTML5',
#   'Ratings': '87%',
#   'Players': '216682'}]

# %% [markdown]
# From the above, we have extracted the list of games data

# %% [markdown]
# ### Step:4 Read and save the extracted information as CSV files
#
# Here we have defined a `write_csv function` to separate `keys` and `values` from `dictionary`

# %%
def write_csv(items, path):
    # Open the file in write mode
    with open(path, 'w') as f:
        # Return if there's nothing to write
        if len(items) == 0:
            return
        
        # Write the headers in the first line
        headers = list(items[0].keys())
        f.write(','.join(headers) + '\n')
        
        # Write one item per line
        for item in items:
            values = []
            for header in headers:
                values.append(str(item.get(header, "")))
            f.write(','.join(values) + "\n")

# %%
write_csv(top_games, 'Games.csv')

# %%
with open('Games.csv', 'r') as file:
    print(file.read())
# Out:
# Game,Technology,Ratings,Players
# Mineclone 3,WebGL,78%,13076707
# Brawl Bash,WebGL,77%,71009
# Hard Life,HTML5,67%,525360
# The Backrooms,WebGL,51%,104878
# Light in the Dark,HTML5,76%,7623
# Police Chase Real Cop Driver,WebGL,79%,1490237
# Zombie Horde,WebGL,88%,2992
# Stick Fighter 3D,WebGL,69%,167090
# Creepy Evil Granny,WebGL,76%,78681
# Kogama: Piggy,WebGL,89%,11019
# Stickman Boost!,HTML5,72%,4979446
# Fireboy And Watergirl Light Temple,HTML5,85%,83397838
# Pants,HTML5,91%,12725
# Samurai Warrios,WebGL,91%,29641
# Cave Jumper,WebGL,77%,3190
# Locoman,HTML5,67%,3138
# Castle of Magic,HTML5,80%,4371
# Minescrafter: Steve and Alex,HTML5,75%,18567
# Lick 'em All,HTML5,66%,1786470
# Bomb It 6,HTML5,88%,29547593
# Chef Quest,HTML5,93%,1839
# A Flying Machine,HTML5,75%,29825
# Clickventure: Castaway,WebGL,80%,13015
# Super Hot,WebGL,81%,2897474
# Hall of Palettes,HTML5,82%,1605
# Total Darkness,HTML5,92%,15271
# Vex 5,HTML5,81%,847362
# Trapdoor,HTML5,54%,699068
# Impostor,HTML5,78%,4381048
# Pixel Challenge,HTML5,68%,18067
# Bomb It 4,HTML5,87%,23802823
# Monkey Go Happy Stage 481,HTML5,71%,65482
# Ascent,HTML5,71%,5584
# Tom and Jerry: Don't Make A Mess,HTML5,89%,57464
# Let's Kill Jeff the Killer: The Asylum,WebGL,81%,48152
# Steve Ball Temple,HTML5,62%,1855
# Spacescape,HTML5,67%,7839
# The Caribbean Sea 3D,WebGL,83%,181494
# Mom is Gone,WebGL,88%,36966
# We're Imposter,WebGL,87%,105193
# Vex 6,HTML5,74%,365665
# Rocking Sky Trip,WebGL,75%,13990176
# EvoWars io,HTML5,77%,41890898
# Moon Battle Royale,WebGL,73%,44693
# Animal Crackers,WebGL,88%,4985
# Hero 2: Super Kick,WebGL,81%,641920
# Dino Rush,WebGL,93%,2903
# Mike & Munk,HTML5,82%,9837
# The Railroad to Elsewhere,WebGL,88%,16480
# Long Live the King!,WebGL,86%,12131
# Brave Explorers,HTML5,94%,6066
# Grandpa Run 3D,WebGL,85%,12892364
# Nenetl,WebGL,73%,1660
# Rorty,HTML5,83%,13241
# The Grand Escape of Dielucard,WebGL,73%,8585
# Error#54,WebGL,74%,1228951
# StarCatcher,HTML5,80%,2741
# Cube Craft Survival,WebGL,88%,19866
# Police Cop Driver Simulator,WebGL,79%,255957
# Bad Ben,WebGL,79%,95989
# Vex 4,HTML5,81%,2753991
# Phineas & Ferb: Transportinators of Doooom,Unity 3D,89%,8936768
# Scooby-Doo and Guess Who: Ghost Creator,HTML5,78%,25199
# 10-103,WebGL,91%,70354

# %% [markdown]
# The below Image is belongs to `Games.csv` in .csv format
#
# ![img](https://i.imgur.com/qZ8iKkl.jpg)

# %% [markdown]
# As per the above, we have extracted and converted the data into `csv format` and saved the file as `.csv`

# %% [markdown]
# ### Complete reusable function code in single cell

# %% [markdown]
# By joining all the above reusable functions we'll get a single function through which we and get information about games

# %%
import requests
from bs4 import BeautifulSoup
topic_url = 'https://www.y8.com/tags/'

# 
def scrape_topic_games(url, path = None):
    if path is None:
        path = url + '.csv'
    topic_page_doc = get_topic_page(url)
    top_games = get_top_games(topic_page_doc)
    write_csv(top_games, path)
    print('Top games for topic "{}" written to file "{}"'.format(url, path))
    return path

#
def get_topic_page(url):
    topic_url = 'https://www.y8.com/tags/' + url
    response = requests.get(topic_url)
    if response.status_code != 200:
        print('Status Code = ', response.status_code)
        raise Exception('failed to fetch web page' + topic_url)
        
    topic_doc = BeautifulSoup(response.text)
    return topic_doc

#
def get_top_games(doc):
    div_tags = doc.find_all('div', class_='item thumb videobox grid-column')
    top_games = [parse_top_games(a) for a in div_tags]
    return top_games

#
def parse_top_games(abc):
    
    h4_tags = abc.find('h4')
    
    name = h4_tags.text.strip()
    
    tech = abc.find('div', class_='item__technology')
    technology = tech.text.strip()
    
    rate = abc.find(class_='item__number')
    ratings = rate.text.strip()
    
    play = abc.find('p', class_='item__plays-count')
    player = play.text.strip()
    players = player[:-6].replace(',','')
    
    return {
        
        'Game' : name,
        'Technology' : technology,
        'Ratings' : ratings,
        'Players' : players
    }

#
def write_csv(items, path):
    # Open the file in write mode
    with open(path, 'w') as f:
        # Return if there's nothing to write
        if len(items) == 0:
            return
        
        # Write the headers in the first line
        headers = list(items[0].keys())
        f.write(','.join(headers) + '\n')
        
        # Write one item per line
        for item in items:
            values = []
            for header in headers:
                values.append(str(item.get(header, "")))
            f.write(','.join(values) + "\n")

# %%
scrape_topic_games('action')
# Out:
# Top games for topic "action" written to file "action.csv"
# 'action.csv'

# %%
# !head action.csv
# Out:
# Game,Technology,Ratings,Players
# Mini Samurai: Kurofune,WebGL,87%,18023
# Diary of a Wimpy Kid: The Meltdown,HTML5,88%,116225
# Stained Act 1,WebGL,81%,137812
# LA Shark,WebGL,76%,1454426
# Madness: Off-Color,HTML5,87%,216682
# Shooter Rush,HTML5,81%,167605
# Call of Mini Zombies,WebGL,81%,20864
# Giant Wanted,WebGL,80%,8872
# Alien Survival 2022,WebGL,72%,44558

# %%
scrape_topic_games('action?page=2')
# Out:
# Top games for topic "action?page=2" written to file "action?page=2.csv"
# 'action?page=2.csv'

# %%
# !head action?page=2.csv
# Out:
# Game,Technology,Ratings,Players
# Protektor,HTML5,88%,18425
# Rum & Gun,WebGL,76%,103865
# Dead Zed,HTML5,85%,5170996
# The Patriots: Fight and Freedom,WebGL,81%,24524
# Vex 3,HTML5,81%,34569171
# Striker Dummies,WebGL,80%,530734
# Fireboy and Watergirl Forest Temple,HTML5,78%,71365324
# Battle for the Galaxy,WebGL,92%,1167792
# Death Lab,HTML5,89%,108610

# %%
scrape_topic_games('action?page=3')
# Out:
# Top games for topic "action?page=3" written to file "action?page=3.csv"
# 'action?page=3.csv'

# %%
# !head action?page=3.csv
# Out:
# Game,Technology,Ratings,Players
# Jungle Treasure,HTML5,75%,27812
# Chaos Roadkill,WebGL,71%,17814
# Battle Royale Gangs,WebGL,90%,851571
# Amazing Crime Strange Stickman - Rope Vice Vegas,WebGL,87%,1026302
# Polygon Royale Shooter,WebGL,81%,15200
# Uphill Halloween Racing,WebGL,77%,32966
# Red Crucible 2,WebGL,88%,11478050
# Mixed Macho Arts,HTML5,85%,368820
# Dexomon,HTML5,75%,185110

# %%
scrape_topic_games('action?page=4')
# Out:
# Top games for topic "action?page=4" written to file "action?page=4.csv"
# 'action?page=4.csv'

# %%
# !head action?page=4.csv
# Out:
# Game,Technology,Ratings,Players
# Black Panther: Jungle Pursuit,HTML5,83%,36488
# Die Alone,HTML5,76%,29816
# Metal Guns Fury,HTML5,82%,164027
# Drakensang Online,HTML5,85%,2943379
# The Office Guy,HTML5,69%,19373
# Ragdoll io,WebGL,82%,240149
# Cube Battle Royale,HTML5,80%,258585
# Zombie Train,WebGL,92%,4245
# Space Marines,WebGL,78%,449699

# %%
scrape_topic_games('action?page=5')
# Out:
# Top games for topic "action?page=5" written to file "action?page=5.csv"
# 'action?page=5.csv'

# %%
# !head action?page=5.csv
# Out:
# Game,Technology,Ratings,Players
# Sun Wukong vs Robot,HTML5,72%,7911
# Waaaar io,HTML5,66%,134093
# Day of Danger - Henry Danger,HTML5,85%,15828
# Lords of the Arena,HTML5,86%,230382
# City Siege 4 - Alien Siege,HTML5,93%,187962
# Epic War,HTML5,87%,307406
# Masked Forces Vs Coronavirus,WebGL,88%,20983
# City Siege,HTML5,86%,386746
# Street Fight,HTML5,81%,130861

# %%
scrape_topic_games('action?page=6')
# Out:
# Top games for topic "action?page=6" written to file "action?page=6.csv"
# 'action?page=6.csv'

# %%
# !head action?page=6.csv
# Out:
# Game,Technology,Ratings,Players
# Captain Rogers: Defense of Karmax-3,HTML5,57%,104413
# Furious Road,HTML5,78%,121741
# Burnin' Rubber,HTML5,76%,42342
# Real Shooting FPS Strike,WebGL,79%,30391
# Block Pixel Cops,WebGL,77%,28810
# City Siege Faction Island,HTML5,94%,7319
# Imposter Killer,WebGL,71%,9493
# Robot Wars,HTML5,81%,15501
# Minerest,WebGL,83%,3836

# %%
scrape_topic_games('action?page=7')
# Out:
# Top games for topic "action?page=7" written to file "action?page=7.csv"
# 'action?page=7.csv'

# %%
# !head action?page=7.csv
# Out:
# Game,Technology,Ratings,Players
# CAD War 4,WebGL,81%,30564
# Tank Arena Game,HTML5,78%,142183
# Army Combat 3D,WebGL,85%,266130
# Jet Boi,HTML5,71%,295187
# FZ Tap Touch Run,HTML5,48%,13007
# Panzer Hero,HTML5,65%,133739
# Ezender Keeper,WebGL,79%,46651
# 300: Seize Your Glory,Unity 3D,91%,1029915
# State Police "Police Bike City Simulator",WebGL,78%,56792

# %%
scrape_topic_games('action?page=8')
# Out:
# Top games for topic "action?page=8" written to file "action?page=8.csv"
# 'action?page=8.csv'

# %%
# !head action?page=8.csv
# Out:
# Game,Technology,Ratings,Players
# Ben 10: The Lost World,Unity 3D,85%,122730
# Colossal Catastrophe – Tom and Jerry,Unity 3D,91%,41225
# Thor's Hammer,Unity 3D,67%,7671
# Stephen Karsch,HTML5,82%,13611
# Crazy Car Driver,WebGL,80%,101402
# Spin Shot,HTML5,84%,9138
# Guardians of the Kingdoms,WebGL,65%,26102
# Dynamons,HTML5,87%,1086151
# Galaxy Aggression 2,HTML5,89%,5403

# %%
scrape_topic_games('action?page=9')
# Out:
# Top games for topic "action?page=9" written to file "action?page=9.csv"
# 'action?page=9.csv'

# %%
# !head action?page=9.csv
# Out:
# Game,Technology,Ratings,Players
# Space Ripper,WebGL,87%,4374
# Pick Your Poison Remix,HTML5,81%,3527
# Marine Invaders,WebGL,68%,30873
# Me and Dungeons,WebGL,82%,11030
# Air Warfare,HTML5,76%,60140
# Grenade Toss,HTML5,62%,22174
# Grandma Chainsaw Action,WebGL,89%,4993
# Aliens Attack,HTML5,60%,18176
# Galactic Missile Defense,HTML5,88%,9637

# %%
scrape_topic_games('action?page=10')
# Out:
# Top games for topic "action?page=10" written to file "action?page=10.csv"
# 'action?page=10.csv'

# %%
# !head action?page=10.csv
# Out:
# Game,Technology,Ratings,Players
# Mission Ammunition,WebGL,84%,13035
# City Escape 2,WebGL,56%,4187
# T-Rex N.Y Online,HTML5,89%,25957
# Chop Chop Ninja Academy,HTML5,81%,12378
# Aliens Gone Wild,HTML5,88%,10184
# Smook Shoodoo,HTML5,67%,7092
# Heist Run,WebGL,66%,7650
# Strited 2D,WebGL,79%,5573
# Masters of the Universe,HTML5,79%,13100

# %% [markdown]
# ### Step:6 Combine data from multiple pages by importing pandas

# %%
import pandas as pd

# %% [markdown]
# By reading the csv file using pandas we can create a data frame.
#
# Which is shown below.

# %%
games1 = pd.read_csv('action.csv', index_col=False)

# %%
games1
# Out:
#                                   Game Technology Ratings   Players
# 0               Mini Samurai: Kurofune      WebGL     87%     18023
# 1   Diary of a Wimpy Kid: The Meltdown      HTML5     88%    116225
# 2                        Stained Act 1      WebGL     81%    137812
# 3                             LA Shark      WebGL     76%   1454426
# 4                   Madness: Off-Color      HTML5     87%    216682
# ..                                 ...        ...     ...       ...
# 59                       Crime City 3D      WebGL     88%  17382987
# 60                     Galactic Forces      WebGL     82%    324946
# 61              Warmerise Lite Version      WebGL     90%  10972447
# 62                      Punch The Wall      WebGL     60%     20808
# 63                      The Royal Hero      WebGL     86%      7245
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action.csv` file
#
# ![img](https://i.imgur.com/ZDiPGKt.jpg)

# %%
games2 = pd.read_csv('action?page=2.csv')

# %%
games2
# Out:
#                                  Game Technology Ratings   Players
# 0                           Protektor      HTML5     88%     18425
# 1                           Rum & Gun      WebGL     76%    103865
# 2                            Dead Zed      HTML5     85%   5170996
# 3     The Patriots: Fight and Freedom      WebGL     81%     24524
# 4                               Vex 3      HTML5     81%  34569171
# ..                                ...        ...     ...       ...
# 59   Streets Of Anarchy: Fists Of War      WebGL     73%     43437
# 60       Squid Escape: Bloody Revenge      WebGL     90%     18542
# 61  Zombie Apocalypse Tunnel Survival      WebGL     92%     50030
# 62                   Inferno Meltdown      HTML5     88%    121292
# 63                   Mad Day: Special      WebGL     86%     22511
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action?page=2.csv` file
# ![img](https://i.imgur.com/ZZ1MRXb.jpg)

# %%
games3 = pd.read_csv('action?page=3.csv')

# %%
games3
# Out:
#                                                 Game Technology Ratings  \
# 0                                    Jungle Treasure      HTML5     75%
# 1                                     Chaos Roadkill      WebGL     71%
# 2                                Battle Royale Gangs      WebGL     90%
# 3   Amazing Crime Strange Stickman - Rope Vice Vegas      WebGL     87%
# 4                             Polygon Royale Shooter      WebGL     81%
# ..                                               ...        ...     ...
# 59                                   Piratebattle io      HTML5     73%
# 60                                   Crime City 3D 2      WebGL     89%
# 61                                     Jack O Gunner      HTML5     60%
# 62                                    Ponypocalypsis      WebGL     74%
# 63                                          Loetanks      HTML5     66%
#
#     Players
# 0     27812
# 1     17814
# 2    851571
# 3   1026302
# 4     15200
# ..      ...
# 59   233186
# 60  8813506
# 61     7424
# 62    16417
# 63    14032
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action?page=3.csv` file
# ![img](https://i.imgur.com/f325nEb.jpg)

# %%
games4 = pd.read_csv('action?page=4.csv')

# %%
games4
# Out:
#                                    Game Technology Ratings   Players
# 0         Black Panther: Jungle Pursuit      HTML5     83%     36488
# 1                             Die Alone      HTML5     76%     29816
# 2                       Metal Guns Fury      HTML5     82%    164027
# 3                     Drakensang Online      HTML5     85%   2943379
# 4                        The Office Guy      HTML5     69%     19373
# ..                                  ...        ...     ...       ...
# 59                            Bomb It 3      HTML5     90%  19419511
# 60                               C-Zero      HTML5     89%     13946
# 61                              Go Repo      HTML5     94%     13024
# 62  Stickman Armed Assassin: Cold Space      WebGL     90%     16833
# 63                  Battalion Commander      HTML5     96%     64534
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action?page=4.csv` file
#
# ![img](https://i.imgur.com/TvQHlLI.jpg)

# %%
games5 = pd.read_csv('action?page=5.csv')

# %%
games5
# Out:
#                             Game Technology Ratings  Players
# 0            Sun Wukong vs Robot      HTML5     72%     7911
# 1                      Waaaar io      HTML5     66%   134093
# 2   Day of Danger - Henry Danger      HTML5     85%    15828
# 3             Lords of the Arena      HTML5     86%   230382
# 4     City Siege 4 - Alien Siege      HTML5     93%   187962
# ..                           ...        ...     ...      ...
# 59                     ForceZ io      WebGL     87%   126231
# 60              Stones of Thanos      HTML5     69%    51689
# 61                 Labyrneath II      HTML5     85%    47536
# 62          Carrot Mania Pirates      HTML5     69%    20568
# 63                 Cyborg Slayer      HTML5     73%    21247
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action?page=5.csv` file
# ![img](https://i.imgur.com/HDixTfG.jpg)

# %%
games6 = pd.read_csv('action?page=6.csv')

# %%
games6
# Out:
#                                    Game Technology Ratings  Players
# 0   Captain Rogers: Defense of Karmax-3      HTML5     57%   104413
# 1                          Furious Road      HTML5     78%   121741
# 2                        Burnin' Rubber      HTML5     76%    42342
# 3              Real Shooting FPS Strike      WebGL     79%    30391
# 4                      Block Pixel Cops      WebGL     77%    28810
# ..                                  ...        ...     ...      ...
# 59                          Way of Hero      HTML5     79%   794608
# 60            WW2 Modern War Tanks 1942      WebGL     83%   165457
# 61     Apple & Onion The Floor is Lava!      HTML5     78%   872937
# 62      Urban Counter Terrorist Warfare      WebGL     80%    97683
# 63                          Ninja Moves      HTML5     90%     8282
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action?page=6.csv` file
# ![img](https://i.imgur.com/Kk9BDNz.jpg)

# %%
games7 = pd.read_csv('action?page=7.csv')

# %%
games7
# Out:
#                            Game Technology Ratings  Players
# 0                     CAD War 4      WebGL     81%    30564
# 1               Tank Arena Game      HTML5     78%   142183
# 2                Army Combat 3D      WebGL     85%   266130
# 3                       Jet Boi      HTML5     71%   295187
# 4              FZ Tap Touch Run      HTML5     48%    13007
# ..                          ...        ...     ...      ...
# 59  Wile Coyote and Road Runner   Unity 3D     84%    33200
# 60                     Seafight      HTML5     83%   899257
# 61               Flick Ninja 3D      HTML5     70%    22211
# 62            SnowBrawl Fight 3   Unity 3D     88%    25586
# 63    Formula Cartoon All Stars   Unity 3D     89%   261574
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action?page=7.csv` file
# ![img](https://i.imgur.com/HfaDaLp.jpg)

# %%
games8 = pd.read_csv('action?page=8.csv')

# %%
games8
# Out:
#                                     Game Technology Ratings  Players
# 0                 Ben 10: The Lost World   Unity 3D     85%   122730
# 1   Colossal Catastrophe – Tom and Jerry   Unity 3D     91%    41225
# 2                          Thor's Hammer   Unity 3D     67%     7671
# 3                         Stephen Karsch      HTML5     82%    13611
# 4                       Crazy Car Driver      WebGL     80%   101402
# ..                                   ...        ...     ...      ...
# 59                     Black Hole Escape      WebGL     80%     4020
# 60                          Robot Escape      WebGL     80%     5647
# 61   Spaceman in the Wizard Alien Nebula      WebGL     70%     3860
# 62                          Discontinuum      WebGL     91%     4304
# 63                            Night Claw      WebGL     85%     5582
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action?page=8.csv` file
# ![img](https://i.imgur.com/JiGFdic.jpg)

# %%
games9 = pd.read_csv('action?page=9.csv')

# %%
games9
# Out:
#                       Game Technology Ratings  Players
# 0             Space Ripper      WebGL     87%     4374
# 1   Pick Your Poison Remix      HTML5     81%     3527
# 2          Marine Invaders      WebGL     68%    30873
# 3          Me and Dungeons      WebGL     82%    11030
# 4              Air Warfare      HTML5     76%    60140
# ..                     ...        ...     ...      ...
# 59           Cactus Mayhem      WebGL     71%     6165
# 60    Warzone Getaway 2020      HTML5     81%   300328
# 61          Swords of Brim      HTML5     63%    16285
# 62            Alpha E Corp      WebGL     72%     7059
# 63           Skeleton Army      HTML5     82%     4086
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action?page=9.csv` file
# ![img](https://i.imgur.com/NvVen3E.jpg)

# %%
games10 = pd.read_csv('action?page=10.csv')

# %%
games10
# Out:
#                        Game Technology Ratings  Players
# 0        Mission Ammunition      WebGL     84%    13035
# 1             City Escape 2      WebGL     56%     4187
# 2          T-Rex N.Y Online      HTML5     89%    25957
# 3   Chop Chop Ninja Academy      HTML5     81%    12378
# 4          Aliens Gone Wild      HTML5     88%    10184
# ..                      ...        ...     ...      ...
# 59             The Last Man      HTML5     82%    26564
# 60                    2Doom      HTML5     91%    12942
# 61            Food Gang Run      HTML5     85%     4969
# 62                 Zedbeard      HTML5     40%     6408
# 63               Asterogues      WebGL     88%     4596
#
# [64 rows x 4 columns]

# %% [markdown]
# Find the below images from `action?page=10.csv` file
# ![img](https://i.imgur.com/I2yl4tk.jpg)

# %%
concat_file = pd.concat([games1, games2, games3, games4, games5, games6, games7, games8, games9, games10], ignore_index=True)

# %% [markdown]
# `. csvfiles`of games1, games2, games3, games4, games5, games6, games7, games8, games9, games10
#
# ![img](https://i.imgur.com/Tjb8ObC.jpg)

# %%
concat_file
# Out:
#                                    Game Technology Ratings  Players
# 0                Mini Samurai: Kurofune      WebGL     87%    18023
# 1    Diary of a Wimpy Kid: The Meltdown      HTML5     88%   116225
# 2                         Stained Act 1      WebGL     81%   137812
# 3                              LA Shark      WebGL     76%  1454426
# 4                    Madness: Off-Color      HTML5     87%   216682
# ..                                  ...        ...     ...      ...
# 635                        The Last Man      HTML5     82%    26564
# 636                               2Doom      HTML5     91%    12942
# 637                       Food Gang Run      HTML5     85%     4969
# 638                            Zedbeard      HTML5     40%     6408
# 639                          Asterogues      WebGL     88%     4596
#
# [640 rows x 4 columns]

# %% [markdown]
# ### Summary
#
# As of now we have:
#
# 1. Download the web page using requests.
# 2. Extracting information from HTML using Beautiful Soup.
# 3. Use Beautiful Soup to parse and extract information (i) Extract Name, Technology, Ratings and Players from the Games, (ii) Compile extracted information into lists and dictionaries,
# 4. Read and save the extracted information as CSV files (i) Complete reusable function code in single cell
# 5. Combine data from multiple pages by importing pandas

# %% [markdown]
# ### Upcoming
#
# * Different categories of Gaming
# * Output the additional information & data's of the Game

# %% [markdown]
# ### Reference Topic's

# %% [markdown]
# * [Web Scraping](https://www.edureka.co/blog/web-scraping-with-python)
#
# * [requests](https://requests.readthedocs.io/en/latest/)
#
# * [BeautifulSoup](https://brightdata.com/blog/how-tos/how-to-use-beautiful-soup-for-web-scraping-with-python?kw=&cpn=14745430544&cam=aw_all_products-all_geos-search_dsa_blog-kw_en-desktop_blog-how-tos__612826796308&utm_term=&utm_campaign=all_products-all_geos-search_dsa_blog-kw_en-desktop&utm_source=adwords&utm_medium=ppc&utm_content=blog-how-tos&hsa_acc=1393175403&hsa_cam=14745430544&hsa_grp=136943771953&hsa_ad=612826796308&hsa_src=g&hsa_tgt=dsa-1649388330704&hsa_kw=&hsa_mt=&hsa_net=adwords&hsa_ver=3&cq_src=google_ads&cq_cmp=14745430544&cq_term=&cq_plac=&cq_net=g&cq_plt=gp&gclid=Cj0KCQiA0oagBhDHARIsAI-BbgfujxVe38gVMoiKaSwNhbdXyYzi17PjrDNR3jPf3VOXh2CCxapHu0AaAgAHEALw_wcB)
#
# * [Pandas](https://www.geeksforgeeks.org/introduction-to-pandas-in-python/)

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "venkatasubramanian-natesan/online-pc-games-s" on https://jovian.com
# [jovian] Committed successfully! https://jovian.com/venkatasubramanian-natesan/online-pc-games-s
# 'https://jovian.com/venkatasubramanian-natesan/online-pc-games-s'
